# %%
# First time
# %cd /content
# !git clone https://github.com/FireMight/point-cloud-retrieval-from-image.git
# %cd /content/point-cloud-retrieval-from-image
# !git submodule update --init --recursive
# %cd ..

# %%
# Pull repository
# %cd /content/point-cloud-retrieval-from-image
# !git pull --recurse-submodules
# %cd ..

# %%
import csv
import os
import sys
import math
import numpy as np
from datetime import datetime
from PIL import Image

# %%
# For Google colab
from google.colab import drive
drive.mount('/content/drive')

sdk_dir = '/content/point-cloud-retrieval-from-image/data/oxford/robotcar-dataset-sdk'
project_dir = '/content/drive/My Drive/ADL4CV'

run_id = 'reference'
data_dir = project_dir + '/downloads/oxford_dataset/' + run_id
gps_dir = data_dir + '/gps'
ins_data_file = gps_dir + '/ins.csv'
extrinsics_dir = sdk_dir + '/extrinsics'

# %%
# For local use
sdk_dir = 'data/oxford/robotcar-dataset-sdk'

run_id = 'reference'
data_dir = 'data/oxford/data/'  + run_id
gps_dir = data_dir + '/gps'
ins_data_file = gps_dir + '/ins.csv'
extrinsics_dir = sdk_dir + '/extrinsics'

# %%
def read_metadata_csv_row(row):
    metadata = {}
    metadata['seg_idx'] = int(row['seg_idx'])
    metadata['timestamp_start'] = int(row['timestamp_start'])
    metadata['northing_start'] = float(row['northing_start'])
    metadata['easting_start'] = float(row['easting_start'])
    metadata['down_start'] = float(row['down_start'])
    metadata['heading_start'] = float(row['heading_start'])
    metadata['timestamp_center'] = int(row['timestamp_center'])
    metadata['northing_center'] = float(row['northing_center'])
    metadata['easting_center'] = float(row['easting_center'])
    metadata['down_center'] = float(row['down_center'])
    metadata['heading_center'] = float(row['heading_center'])
    
    return metadata


def get_pcl_metadata(metadata_file, seg_idx=None):
    if seg_idx is None:
        # Return list of all metadata
        metadata = []
    else:
        # Return metadata of single submap
        metadata = None
        
    with open(metadata_file) as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            if seg_idx is None:
                metadata.append(read_metadata_csv_row(row))
            elif int(row['seg_idx']) == seg_idx:
                metadata = read_metadata_csv_row(row)
                break
    return metadata

# %%
sys.path.insert(0, sdk_dir + '/python')
import image as sdk_image
from camera_model import CameraModel

class ImageLoader():
    def __init__(self, camera_type, center_offset=None):
        self.trajectory_ned = None
        self.subset_split = None
        self.camera_type = camera_type
        self.center_offset = center_offset
        
        if camera_type == 'center':
            self.img_dir = data_dir + '/stereo/centre'
            self.timestamps_file = data_dir + '/stereo.timestamps'
            self.tgt_dir = data_dir + '/img_center'
            if center_offset is not None:
                self.tgt_dir += '_{}'.format(int(center_offset))
        elif camera_type in ['left', 'right']:
            self.img_dir = data_dir + '/mono_{}'.format(camera_type)
            self.timestamps_file = data_dir + '/mono_{}.timestamps'.format(camera_type)
            self.tgt_dir = data_dir + '/img_{}'.format(camera_type)
        else:
            raise ValueError('Wrong camera type: ', camera_type)
        
        if not os.path.isdir(self.tgt_dir):
            os.mkdir(self.tgt_dir)
            
        self.camera_model = CameraModel(sdk_dir + '/models', self.img_dir)
        
    
    def load_ned_trajectory(self, subset_split=None):
        # Get timestamps from camera data
        self.timestamps_file = np.genfromtxt(self.timestamps_file)
        self.timestamps_file = self.timestamps_file[:,0].flatten()
        start_time = self.timestamps_file[0]
        end_time = self.timestamps_file[-1]

        # Check if NED trajectory has already been computed
        trajectory_file = gps_dir + '/ned_trajectory_{}_{}.npy'.format(self.camera_type, 
                                                                       run_id)
        print('Search for precomputed NED trajectory ' + trajectory_file + '...')

        try:
            self.trajectory_ned = np.load(trajectory_file)
            print('Done!')
        except:
            print('Not found! Create camera trajectory...')
            # Get trajectory corresponding to camera data
            camera_timestamp_idx = 0
            self.trajectory_ned = np.empty((7,0))
            with open(ins_data_file, 'r') as ins_file:
                reader = csv.DictReader(ins_file)
                for row in reader:
                    if int(row['timestamp']) > end_time:
                        break
                    if int(row['timestamp']) < start_time:
                        continue

                    # Get closest corresponding camera timestamp
                    ins_timestamp = int(row['timestamp'])
                    camera_timestamp_idx = self.get_closest_camera_timestamp(
                                                ins_timestamp, camera_timestamp_idx)
                    img_timestamp = self.timestamps_file[camera_timestamp_idx]

                    camera_state = np.array([float(row['northing']),
                                             float(row['easting']),
                                             float(row['down']),
                                             float(row['roll']),
                                             float(row['pitch']),
                                             float(row['yaw']),
                                             img_timestamp]).reshape(7,1)
                    self.trajectory_ned = np.append(self.trajectory_ned, camera_state, axis=1)
 
            print('Done! Trajectory with {} samples'.format(
                                                  self.trajectory_ned.shape[1]))

            # Save trajectory
            print('Save NED trajectory to ' + trajectory_file + '...')
            np.save(trajectory_file, self.trajectory_ned)
            print('Done!')
            
        # If specified, use only a subset of the data
        if subset_split is not None:
            max_idx = int(self.trajectory_ned.shape[1] * subset_split)
            print('WARNING: We use only the first {}% of the trajectory ({} measurements)'.
                                                format(int(subset_split*100), max_idx))
            self.trajectory_ned = self.trajectory_ned[:,:max_idx]
            self.subset_split = subset_split
            
    def load_images(self, submap_length):
        # Load pointcloud metadata
        pcl_dir = data_dir + '/submaps_{}m'.format(int(submap_length))
        pcl_metadata_filename = (pcl_dir + '/metadata.csv')
        pcl_metadata = get_pcl_metadata(pcl_metadata_filename)

        # Sort list by timestamp
        pcl_metadata.sort(key=lambda pcl: pcl['timestamp_start'])

        # Create image metadata csv file
        metadata_fieldnames = ['seg_idx',
                               'camera',
                               'offset', 
                               'timestamp',
                               'northing',
                               'easting',
                               'down',
                               'heading', 
                               'dist_to_ref']
        metadata_csv = (self.tgt_dir + '/metadata.csv')

        with open(metadata_csv, 'w') as outcsv:
            writer = csv.DictWriter(outcsv, metadata_fieldnames)
            writer.writeheader()
        
        # Walk along camera trajectory and save all images belonging to a submap
        if self.camera_type == 'center':
            ref = 'start'
            offset = self.center_offset
        else:
            ref = 'center'
            offset = 0
            
        i_pcl = 0
        i_min = 0
        dist_min = 1.0e9
        ref_pos = np.array([pcl_metadata[i_pcl]['northing_'+ref],
                            pcl_metadata[i_pcl]['easting_'+ref]])
                
        for i in range(self.trajectory_ned.shape[1]):
            pos = self.trajectory_ned[:2,i]
            dist_to_ref = np.linalg.norm(pos - ref_pos)

            if dist_to_ref < dist_min:
                i_min = i
                dist_min = dist_to_ref

            if dist_to_ref > dist_min + 0.5:

                # Go back to offset
                if offset > 0:
                    dist_to_offset = offset
                    prev_pos = self.trajectory_ned[:3,i_min]
                    for i_min in range(i_min-1,-1,-1):
                        curr_pos = self.trajectory_ned[[0,1,2],i_min]
                        dist_to_offset -= np.linalg.norm(prev_pos - curr_pos)
                        prev_pos = curr_pos
                        if dist_to_offset < 0:
                            break

                print('Save image {} with dist {}'.format(i_min, dist_min))
                # Save image of step with minimum dist to reference as png
                timestamp = self.trajectory_ned[6,i_min]
                seg_idx = pcl_metadata[i_pcl]['seg_idx']

                _, pil_image = self.load_image(timestamp, size=(320,200))
                pil_image.save(self.tgt_dir + '/img_{}_{}.png'.format(submap_length, 
                                                                         seg_idx), 'PNG')

                # Save image metadata
                with open(metadata_csv, 'a') as outcsv:
                    writer = csv.DictWriter(outcsv,fieldnames=metadata_fieldnames)
                    writer.writerow({'seg_idx' : seg_idx,
                                     'camera' : self.camera_type,
                                     'offset' : self.center_offset, 
                                     'timestamp' : int(timestamp),
                                     'northing' : self.trajectory_ned[0,i_min],
                                     'easting' : self.trajectory_ned[1,i_min],
                                     'down' : self.trajectory_ned[2,i_min],
                                     'heading' : self.trajectory_ned[5,i_min], 
                                     'dist_to_ref' : dist_min})


                # Set new reference position
                i_pcl += 1
                if i_pcl == len(pcl_metadata):
                    print('Last submap reached!')
                    break
                ref_pos = np.array([pcl_metadata[i_pcl]['northing_'+ref],
                                    pcl_metadata[i_pcl]['easting_'+ref]])
                dist_min = 1.0e9
            
        
    
    def get_closest_camera_timestamp(self, ins_timestamp, start_idx):
        min_diff = 1e9
        i_min = start_idx
        for i in range(start_idx, self.timestamps_file.shape[0]):
            diff = math.fabs(ins_timestamp - self.timestamps_file[i])

            if diff < min_diff:
                min_diff = diff
                i_min = i
            else:
                break

        return i_min
    
    def load_image(self, timestamp, size=None):
        image_file = os.path.join(self.img_dir, '{}.png'.format(int(timestamp)))
        image = sdk_image.load_image(image_file, model=self.camera_model)

        pil_image = Image.fromarray(image.astype('uint8'))
        if size is not None:
            pil_image = pil_image.resize(size)

        return image, pil_image

# %%
camera_type = 'center'
offset = 5
submap_length = 20

img_loader = ImageLoader(camera_type, center_offset=offset)
img_loader.load_ned_trajectory(subset_split=0.2)
img_loader.load_images(submap_length)
# Out:
# Search for precomputed NED trajectory data/oxford/data/reference/gps/ned_trajectory_center_reference.npy...
# Done!
# WARNING: We use only the first 20% of the trajectory (23656 measurements)
# Save image 0 with dist 0.0
# Save image 0 with dist 0.008607375699784094
# Save image 0 with dist 0.0
# Save image 0 with dist 0.0
# Save image 805 with dist 0.0
# Save image 835 with dist 0.0
# Save image 875 with dist 0.0
# Save image 895 with dist 0.0
# Save image 929 with dist 0.0
# Save image 948 with dist 0.0
# Save image 972 with dist 0.0
# Save image 991 with dist 0.0
# Save image 1010 with dist 0.0
# Save image 1028 with dist 0.0
# Save image 1042 with dist 0.0
# Save image 1057 with dist 0.0
# Save image 1072 with dist 0.0
# Save image 1086 with dist 0.0
# Save image 1099 with dist 0.0
# Save image 1113 with dist 0.0
# Save image 1126 with dist 0.0
# Save image 1138 with dist 0.0
# Save image 1151 with dist 0.0
# Save image 1164 with dist 0.0
# Save image 1176 with dist 0.0
# Save image 1188 with dist 0.0
# Save image 1200 with dist 0.0
# Save image 1212 with dist 0.0
# Save image 1223 with dist 0.0
# Save image 1236 with dist 0.0
# Save image 1248 with dist 0.0
# Save image 1261 with dist 0.0
# Save image 1274 with dist 0.0
# Save image 1287 with dist 0.0
# Save image 1300 with dist 0.0
# Save image 1317 with dist 0.0
# Save image 1329 with dist 0.0
# Save image 1341 with dist 0.0
# Save image 1357 with dist 0.0
# Save image 1373 with dist 0.0
# Save image 1386 with dist 0.0
# Save image 1404 with dist 0.0
# Save image 1423 with dist 0.0
# Save image 1443 with dist 0.0
# Save image 1465 with dist 0.0
# Save image 1491 with dist 0.0
# Save image 1520 with dist 0.0
# Save image 1554 with dist 0.0
# Save image 1587 with dist 0.0
# Save image 1713 with dist 0.7868943886303627
# Save image 1740 with dist 0.8081923626165739
# Save image 1791 with dist 0.9482736761028966
# Save image 1825 with dist 0.5126266885832527
# Save image 1934 with dist 0.5161565425799821
# Save image 2032 with dist 0.04588771987500097
# Save image 2535 with dist 0.0
# Save image 2560 with dist 0.0
# Save image 2587 with dist 0.0
# Save image 2605 with dist 0.0
# Save image 2627 with dist 0.0
# Save image 2648 with dist 0.0
# Save image 2672 with dist 0.0
# Save image 2693 with dist 0.0
# Save image 2743 with dist 0.30261418097257725
# Save image 2775 with dist 0.3205862015654537
# Save image 2802 with dist 0.0
# Save image 2867 with dist 0.0
# Save image 2987 with dist 0.0
# Save image 4132 with dist 0.0
# Save image 4442 with dist 0.0
# Save image 4473 with dist 0.0
# Save image 4488 with dist 0.0
# Save image 4507 with dist 0.0
# Save image 4523 with dist 0.0
# Save image 4535 with dist 0.0
# Save image 4545 with dist 0.0
# Save image 4556 with dist 0.0
# Save image 4566 with dist 0.0
# Save image 4577 with dist 0.0
# Save image 4585 with dist 0.0
# Save image 4592 with dist 0.0
# Save image 4601 with dist 0.0
# Save image 4609 with dist 0.0
# Save image 4616 with dist 0.0
# Save image 4624 with dist 0.0
# Save image 4632 with dist 0.0
# Save image 4638 with dist 0.0
# Save image 4646 with dist 0.0
# Save image 4653 with dist 0.0
# Save image 4661 with dist 0.0
# Save image 4669 with dist 0.0
# Save image 4676 with dist 0.0
# Save image 4684 with dist 0.0
# Save image 4691 with dist 0.0
# Save image 4699 with dist 0.0
# Save image 4707 with dist 0.0
# Save image 4715 with dist 0.0
# Save image 4723 with dist 0.0
# Save image 4731 with dist 0.0
# Save image 4739 with dist 0.0
# Save image 4747 with dist 0.0
# Save image 4757 with dist 0.0
# Save image 4765 with dist 0.0
# Save image 4775 with dist 0.0
# Save image 4784 with dist 0.0
# Save image 4794 with dist 0.0
# Save image 4804 with dist 0.0
# Save image 4815 with dist 0.0
# Save image 4827 with dist 0.0
# Save image 4839 with dist 0.0
# Save image 4852 with dist 0.0
# Save image 4867 with dist 0.0
# Save image 4884 with dist 0.0
# Save image 4900 with dist 0.0
# Save image 4918 with dist 0.0
# Save image 4935 with dist 0.0
# Save image 4952 with dist 0.0
# Save image 4966 with dist 0.0
# Save image 4979 with dist 0.0
# Save image 4991 with dist 0.0
# Save image 5003 with dist 0.0
# Save image 5013 with dist 0.0
# Save image 5023 with dist 0.0
# Save image 5033 with dist 0.0
# Save image 5043 with dist 0.0
# Save image 5053 with dist 0.0
# Save image 5063 with dist 0.0
# Save image 5072 with dist 0.0
# Save image 5081 with dist 0.0
# Save image 5089 with dist 0.0
# Save image 5097 with dist 0.0
# Save image 5106 with dist 0.0
# Save image 5114 with dist 0.0
# Save image 5123 with dist 0.0
# Save image 5131 with dist 0.0
# Save image 5139 with dist 0.0
# Save image 5147 with dist 0.0
# Save image 5156 with dist 0.0
# Save image 5164 with dist 0.0
# Save image 5172 with dist 0.0
# Save image 5180 with dist 0.0
# Save image 5188 with dist 0.0
# Save image 5196 with dist 0.0
# Save image 5204 with dist 0.0
# Save image 5211 with dist 0.0
# Save image 5219 with dist 0.0
# Save image 5227 with dist 0.0
# Save image 5235 with dist 0.0
# Save image 5242 with dist 0.0
# Save image 5250 with dist 0.0
# Save image 5258 with dist 0.0
# Save image 5266 with dist 0.0
# Save image 5275 with dist 0.0
# Save image 5283 with dist 0.0
# Save image 5291 with dist 0.0
# Save image 5299 with dist 0.0
# Save image 5308 with dist 0.0
# Save image 5316 with dist 0.0
# Save image 5324 with dist 0.0
# Save image 5332 with dist 0.0
# Save image 5341 with dist 0.0
# Save image 5349 with dist 0.0
# Save image 5357 with dist 0.0
# Save image 5365 with dist 0.0
# Save image 5373 with dist 0.0
# Save image 5381 with dist 0.0
# Save image 5389 with dist 0.0
# Save image 5397 with dist 0.0
# Save image 5405 with dist 0.0
# Save image 5412 with dist 0.0
# Save image 5419 with dist 0.0
# Save image 5426 with dist 0.0
# Save image 5433 with dist 0.0
# Save image 5440 with dist 0.0
# Save image 5447 with dist 0.0
# Save image 5454 with dist 0.0
# Save image 5461 with dist 0.0
# Save image 5468 with dist 0.0
# Save image 5475 with dist 0.0
# Save image 5482 with dist 0.0
# Save image 5489 with dist 0.0
# Save image 5496 with dist 0.0
# Save image 5503 with dist 0.0
# Save image 5510 with dist 0.0
# Save image 5517 with dist 0.0
# Save image 5524 with dist 0.0
# Save image 5531 with dist 0.0
# Save image 5538 with dist 0.0
# Save image 5546 with dist 0.0
# Save image 5553 with dist 0.0
# Save image 5560 with dist 0.0
# Save image 5567 with dist 0.0
# Save image 5574 with dist 0.0
# Save image 5581 with dist 0.0
# Save image 5588 with dist 0.0
# Save image 5595 with dist 0.0
# Save image 5602 with dist 0.0
# Save image 5609 with dist 0.0
# Save image 5616 with dist 0.0
# Save image 5623 with dist 0.0
# Save image 5630 with dist 0.0
# Save image 5637 with dist 0.0
# Save image 5644 with dist 0.0
# Save image 5651 with dist 0.0
# Save image 5658 with dist 0.0
# Save image 5665 with dist 0.0
# Save image 5672 with dist 0.0
# Save image 5679 with dist 0.0
# Save image 5686 with dist 0.0
# Save image 5694 with dist 0.0
# Save image 5701 with dist 0.0
# Save image 5708 with dist 0.0
# Save image 5715 with dist 0.0
# Save image 5723 with dist 0.0
# Save image 5730 with dist 0.0
# Save image 5737 with dist 0.0
# Save image 5744 with dist 0.0
# Save image 5751 with dist 0.0
# Save image 5758 with dist 0.0
# Save image 5765 with dist 0.0
# Save image 5772 with dist 0.0
# Save image 5779 with dist 0.0
# Save image 5786 with dist 0.0
# Save image 5793 with dist 0.0
# Save image 5800 with dist 0.0
# Save image 5807 with dist 0.0
# Save image 5813 with dist 0.0
# Save image 5820 with dist 0.0
# Save image 5827 with dist 0.0
# Save image 5834 with dist 0.0
# Save image 5840 with dist 0.0
# Save image 5847 with dist 0.0
# Save image 5854 with dist 0.0
# Save image 5861 with dist 0.0
# Save image 5868 with dist 0.0
# Save image 5875 with dist 0.0
# Save image 5881 with dist 0.0
# Save image 5888 with dist 0.0
# Save image 5896 with dist 0.0
# Save image 5903 with dist 0.0
# Save image 5911 with dist 0.0
# Save image 5918 with dist 0.0
# Save image 5926 with dist 0.0
# Save image 5934 with dist 0.0
# Save image 5941 with dist 0.0
# Save image 5949 with dist 0.0
# Save image 5957 with dist 0.0
# Save image 5965 with dist 0.0
# Save image 5972 with dist 0.0
# Save image 5980 with dist 0.0
# Save image 5988 with dist 0.0
# Save image 5997 with dist 0.0
# Save image 6004 with dist 0.0
# Save image 6012 with dist 0.0
# Save image 6020 with dist 0.0
# Save image 6027 with dist 0.0
# Save image 6035 with dist 0.0
# Save image 6042 with dist 0.0
# Save image 6050 with dist 0.0
# Save image 6057 with dist 0.0
# Save image 6065 with dist 0.0
# Save image 6072 with dist 0.0
# Save image 6079 with dist 0.0
# Save image 6086 with dist 0.0
# Save image 6094 with dist 0.0
# Save image 6101 with dist 0.0
# Save image 6108 with dist 0.0
# Save image 6114 with dist 0.0
# Save image 6121 with dist 0.0
# Save image 6127 with dist 0.0
# Save image 6133 with dist 0.0
# Save image 6139 with dist 0.0
# Save image 6145 with dist 0.0
# Save image 6152 with dist 0.0
# Save image 6158 with dist 0.0
# Save image 6164 with dist 0.0
# Save image 6170 with dist 0.0
# Save image 6176 with dist 0.0
# Save image 6182 with dist 0.0
# Save image 6189 with dist 0.0
# Save image 6195 with dist 0.0
# Save image 6201 with dist 0.0
# Save image 6207 with dist 0.0
# Save image 6213 with dist 0.0
# Save image 6219 with dist 0.0
# Save image 6225 with dist 0.0
# Save image 6231 with dist 0.0
# Save image 6237 with dist 0.0
# Save image 6243 with dist 0.0
# Save image 6249 with dist 0.0
# Save image 6255 with dist 0.0
# Save image 6261 with dist 0.0
# Save image 6267 with dist 0.0
# Save image 6273 with dist 0.0
# Save image 6279 with dist 0.0
# Save image 6285 with dist 0.0
# Save image 6291 with dist 0.0
# Save image 6297 with dist 0.0
# Save image 6303 with dist 0.0
# Save image 6310 with dist 0.0
# Save image 6316 with dist 0.0
# Save image 6322 with dist 0.0
# Save image 6328 with dist 0.0
# Save image 6334 with dist 0.0
# Save image 6339 with dist 0.0
# Save image 6345 with dist 0.0
# Save image 6351 with dist 0.0
# Save image 6357 with dist 0.0
# Save image 6363 with dist 0.0
# Save image 6369 with dist 0.0
# Save image 6375 with dist 0.0
# Save image 6381 with dist 0.0
# Save image 6386 with dist 0.0
# Save image 6392 with dist 0.0
# Save image 6398 with dist 0.0
# Save image 6404 with dist 0.0
# Save image 6409 with dist 0.0
# Save image 6415 with dist 0.0
# Save image 6421 with dist 0.0
# Save image 6427 with dist 0.0
# Save image 6433 with dist 0.0
# Save image 6438 with dist 0.0
# Save image 6444 with dist 0.0
# Save image 6450 with dist 0.0
# Save image 6456 with dist 0.0
# Save image 6462 with dist 0.0
# Save image 6468 with dist 0.0
# Save image 6474 with dist 0.0
# Save image 6480 with dist 0.0
# Save image 6485 with dist 0.0
# Save image 6491 with dist 0.0
# Save image 6497 with dist 0.0
# Save image 6503 with dist 0.0
# Save image 6509 with dist 0.0
# Save image 6515 with dist 0.0
# Save image 6521 with dist 0.0
# Save image 6527 with dist 0.0
# Save image 6533 with dist 0.0
# Save image 6538 with dist 0.0
# Save image 6544 with dist 0.0
# Save image 6551 with dist 0.0
# Save image 6557 with dist 0.0
# Save image 6564 with dist 0.0
# Save image 6571 with dist 0.0
# Save image 6578 with dist 0.0
# Save image 6584 with dist 0.0
# Save image 6591 with dist 0.0
# Save image 6597 with dist 0.0
# Save image 6605 with dist 0.0
# Save image 6612 with dist 0.0
# Save image 6619 with dist 0.0
# Save image 6625 with dist 0.0
# Save image 6632 with dist 0.0
# Save image 6638 with dist 0.0
# Save image 6644 with dist 0.0
# Save image 6653 with dist 0.0
# Save image 6660 with dist 0.0
# Save image 6667 with dist 0.0
# Save image 6674 with dist 0.0
# Save image 6681 with dist 0.0
# Save image 6688 with dist 0.0
# Save image 6696 with dist 0.0
# Save image 6704 with dist 0.0
# Save image 6712 with dist 0.0
# Save image 6720 with dist 0.0
# Save image 6729 with dist 0.0
# Save image 6737 with dist 0.0
# Save image 6747 with dist 0.0
# Save image 6756 with dist 0.0
# Save image 6766 with dist 0.0
# Save image 6777 with dist 0.0
# Save image 6788 with dist 0.0
# Save image 6799 with dist 0.0
# Save image 6812 with dist 0.0
# Save image 6825 with dist 0.0
# Save image 6839 with dist 0.0
# Save image 6854 with dist 0.0
# Save image 6871 with dist 0.0
# Save image 6888 with dist 0.0
# Save image 6913 with dist 0.0
# Save image 6951 with dist 0.0
# Save image 7087 with dist 0.0
# Save image 7135 with dist 0.0
# Save image 7155 with dist 0.0
# Save image 7170 with dist 0.0
# Save image 7183 with dist 0.0
# Save image 7193 with dist 0.0
# Save image 7204 with dist 0.0
# Save image 7213 with dist 0.0
# Save image 7222 with dist 0.0
# Save image 7231 with dist 0.0
# Save image 7238 with dist 0.0
# Save image 7246 with dist 0.0
# Save image 7253 with dist 0.0
# Save image 7260 with dist 0.0
# Save image 7267 with dist 0.0
# Save image 7274 with dist 0.0
# Save image 7281 with dist 0.0
# Save image 7287 with dist 0.0
# Save image 7294 with dist 0.0
# Save image 7300 with dist 0.0
# Save image 7305 with dist 0.0
# Save image 7311 with dist 0.0
# Save image 7316 with dist 0.0
# Save image 7321 with dist 0.0
# Save image 7326 with dist 0.0
# Save image 7331 with dist 0.0
# Save image 7336 with dist 0.0
# Save image 7341 with dist 0.0
# Save image 7346 with dist 0.0
# Save image 7351 with dist 0.0
# Save image 7356 with dist 0.0
# Save image 7362 with dist 0.0
# Save image 7367 with dist 0.0
# Save image 7373 with dist 0.0
# Save image 7379 with dist 0.0
# Save image 7385 with dist 0.0
# Save image 7391 with dist 0.0
# Save image 7397 with dist 0.0
# Save image 7403 with dist 0.0
# Save image 7409 with dist 0.0
# Save image 7415 with dist 0.0
# Save image 7421 with dist 0.0
# Save image 7426 with dist 0.0
# Save image 7431 with dist 0.0
# Save image 7436 with dist 0.0
# Save image 7441 with dist 0.0
# Save image 7446 with dist 0.0
# Save image 7451 with dist 0.0
# Save image 7456 with dist 0.0
# Save image 7461 with dist 0.0
# Save image 7466 with dist 0.0
# Save image 7472 with dist 0.0
# Save image 7477 with dist 0.0
# Save image 7482 with dist 0.0
# Save image 7487 with dist 0.0
# Save image 7492 with dist 0.0
# Save image 7497 with dist 0.0
# Save image 7502 with dist 0.0
# Save image 7507 with dist 0.0
# Save image 7512 with dist 0.0
# Save image 7517 with dist 0.0
# Save image 7522 with dist 0.0
# Save image 7527 with dist 0.0
# Save image 7532 with dist 0.0
# Save image 7537 with dist 0.0
# Save image 7542 with dist 0.0
# Save image 7547 with dist 0.0
# Save image 7552 with dist 0.0
# Save image 7557 with dist 0.0
# Save image 7562 with dist 0.0
# Save image 7567 with dist 0.0
# Save image 7572 with dist 0.0
# Save image 7577 with dist 0.0
# Save image 7582 with dist 0.0
# Save image 7587 with dist 0.0
# Save image 7592 with dist 0.0
# Save image 7597 with dist 0.0
# Save image 7602 with dist 0.0
# Save image 7607 with dist 0.0
# Save image 7612 with dist 0.0
# Save image 7617 with dist 0.0
# Save image 7622 with dist 0.0
# Save image 7627 with dist 0.0
# Save image 7633 with dist 0.0
# Save image 7638 with dist 0.0
# Save image 7643 with dist 0.0
# Save image 7648 with dist 0.0
# Save image 7653 with dist 0.0
# Save image 7658 with dist 0.0
# Save image 7663 with dist 0.0
# Save image 7668 with dist 0.0
# Save image 7673 with dist 0.0
# Save image 7678 with dist 0.0
# Save image 7683 with dist 0.0
# Save image 7688 with dist 0.0
# Save image 7693 with dist 0.0
# Save image 7698 with dist 0.0
# Save image 7703 with dist 0.0
# Save image 7708 with dist 0.0
# Save image 7713 with dist 0.0
# Save image 7718 with dist 0.0
# Save image 7724 with dist 0.0
# Save image 7729 with dist 0.0
# Save image 7734 with dist 0.0
# Save image 7739 with dist 0.0
# Save image 7744 with dist 0.0
# Save image 7749 with dist 0.0
# Save image 7754 with dist 0.0
# Save image 7759 with dist 0.0
# Save image 7764 with dist 0.0
# Save image 7769 with dist 0.0
# Save image 7774 with dist 0.0
# Save image 7779 with dist 0.0
# Save image 7784 with dist 0.0
# Save image 7789 with dist 0.0
# Save image 7794 with dist 0.0
# Save image 7799 with dist 0.0
# Save image 7804 with dist 0.0
# Save image 7809 with dist 0.0
# Save image 7814 with dist 0.0
# Save image 7819 with dist 0.0
# Save image 7824 with dist 0.0
# Save image 7829 with dist 0.0
# Save image 7834 with dist 0.0
# Save image 7839 with dist 0.0
# Save image 7844 with dist 0.0
# Save image 7849 with dist 0.0
# Save image 7854 with dist 0.0
# Save image 7859 with dist 0.0
# Save image 7864 with dist 0.0
# Save image 7869 with dist 0.0
# Save image 7874 with dist 0.0
# Save image 7879 with dist 0.0
# Save image 7884 with dist 0.0
# Save image 7889 with dist 0.0
# Save image 7894 with dist 0.0
# Save image 7899 with dist 0.0
# Save image 7904 with dist 0.0
# Save image 7909 with dist 0.0
# Save image 7914 with dist 0.0
# Save image 7919 with dist 0.0
# Save image 7924 with dist 0.0
# Save image 7929 with dist 0.0
# Save image 7935 with dist 0.0
# Save image 7940 with dist 0.0
# Save image 7945 with dist 0.0
# Save image 7950 with dist 0.0
# Save image 7955 with dist 0.0
# Save image 7960 with dist 0.0
# Save image 7965 with dist 0.0
# Save image 7970 with dist 0.0
# Save image 7975 with dist 0.0
# Save image 7980 with dist 0.0
# Save image 7985 with dist 0.0
# Save image 7990 with dist 0.0
# Save image 7995 with dist 0.0
# Save image 8000 with dist 0.0
# Save image 8005 with dist 0.0
# Save image 8010 with dist 0.0
# Save image 8015 with dist 0.0
# Save image 8020 with dist 0.0
# Save image 8025 with dist 0.0
# Save image 8030 with dist 0.0
# Save image 8035 with dist 0.0
# Save image 8040 with dist 0.0
# Save image 8045 with dist 0.0
# Save image 8050 with dist 0.0
# Save image 8055 with dist 0.0
# Save image 8060 with dist 0.0
# Save image 8065 with dist 0.0
# Save image 8069 with dist 0.0
# Save image 8074 with dist 0.0
# Save image 8079 with dist 0.0
# Save image 8084 with dist 0.0
# Save image 8089 with dist 0.0
# Save image 8094 with dist 0.0
# Save image 8099 with dist 0.0
# Save image 8104 with dist 0.0
# Save image 8109 with dist 0.0
# Save image 8114 with dist 0.0
# Save image 8119 with dist 0.0
# Save image 8124 with dist 0.0
# Save image 8129 with dist 0.0
# Save image 8134 with dist 0.0
# Save image 8139 with dist 0.0
# Save image 8144 with dist 0.0
# Save image 8149 with dist 0.0
# Save image 8154 with dist 0.0
# Save image 8159 with dist 0.0
# Save image 8164 with dist 0.0
# Save image 8169 with dist 0.0
# Save image 8174 with dist 0.0
# Save image 8179 with dist 0.0
# Save image 8184 with dist 0.0
# Save image 8189 with dist 0.0
# Save image 8194 with dist 0.0
# Save image 8199 with dist 0.0
# Save image 8204 with dist 0.0
# Save image 8209 with dist 0.0
# Save image 8214 with dist 0.0
# Save image 8219 with dist 0.0
# Save image 8224 with dist 0.0
# Save image 8229 with dist 0.0
# Save image 8234 with dist 0.0
# Save image 8239 with dist 0.0
# Save image 8244 with dist 0.0
# Save image 8249 with dist 0.0
# Save image 8254 with dist 0.0
# Save image 8259 with dist 0.0
# Save image 8264 with dist 0.0
# Save image 8269 with dist 0.0
# Save image 8274 with dist 0.0
# Save image 8279 with dist 0.0
# Save image 8284 with dist 0.0
# Save image 8289 with dist 0.0
# Save image 8294 with dist 0.0
# Save image 8299 with dist 0.0
# Save image 8304 with dist 0.0
# Save image 8309 with dist 0.0
# Save image 8314 with dist 0.0
# Save image 8319 with dist 0.0
# Save image 8324 with dist 0.0
# Save image 8329 with dist 0.0
# Save image 8334 with dist 0.0
# Save image 8339 with dist 0.0
# Save image 8344 with dist 0.0
# Save image 8349 with dist 0.0
# Save image 8354 with dist 0.0
# Save image 8359 with dist 0.0
# Save image 8364 with dist 0.0
# Save image 8369 with dist 0.0
# Save image 8374 with dist 0.0
# Save image 8379 with dist 0.0
# Save image 8384 with dist 0.0
# Save image 8389 with dist 0.0
# Save image 8393 with dist 0.0
# Save image 8398 with dist 0.0
# Save image 8403 with dist 0.0
# Save image 8408 with dist 0.0
# Save image 8413 with dist 0.0
# Save image 8418 with dist 0.0
# Save image 8423 with dist 0.0
# Save image 8428 with dist 0.0
# Save image 8433 with dist 0.0
# Save image 8438 with dist 0.0
# Save image 8443 with dist 0.0
# Save image 8448 with dist 0.0
# Save image 8453 with dist 0.0
# Save image 8458 with dist 0.0
# Save image 8463 with dist 0.0
# Save image 8468 with dist 0.0
# Save image 8473 with dist 0.0
# Save image 8478 with dist 0.0
# Save image 8483 with dist 0.0
# Save image 8487 with dist 0.0
# Save image 8492 with dist 0.0
# Save image 8497 with dist 0.0
# Save image 8502 with dist 0.0
# Save image 8507 with dist 0.0
# Save image 8513 with dist 0.0
# Save image 8518 with dist 0.0
# Save image 8523 with dist 0.0
# Save image 8528 with dist 0.0
# Save image 8533 with dist 0.0
# Save image 8537 with dist 0.0
# Save image 8542 with dist 0.0
# Save image 8547 with dist 0.0
# Save image 8552 with dist 0.0
# Save image 8557 with dist 0.0
# Save image 8562 with dist 0.0
# Save image 8567 with dist 0.0
# Save image 8572 with dist 0.0
# Save image 8578 with dist 0.0
# Save image 8584 with dist 0.0
# Save image 8589 with dist 0.0
# Save image 8595 with dist 0.0
# Save image 8601 with dist 0.0
# Save image 8607 with dist 0.0
# Save image 8612 with dist 0.0
# Save image 8618 with dist 0.0
# Save image 8624 with dist 0.0
# Save image 8630 with dist 0.0
# Save image 8636 with dist 0.0
# Save image 8642 with dist 0.0
# Save image 8648 with dist 0.0
# Save image 8654 with dist 0.0
# Save image 8660 with dist 0.0
# Save image 8666 with dist 0.0
# Save image 8672 with dist 0.0
# Save image 8678 with dist 0.0
# Save image 8683 with dist 0.0
# Save image 8689 with dist 0.0
# Save image 8695 with dist 0.0
# Save image 8701 with dist 0.0
# Save image 8707 with dist 0.0
# Save image 8713 with dist 0.0
# Save image 8719 with dist 0.0
# Save image 8724 with dist 0.0
# Save image 8730 with dist 0.0
# Save image 8736 with dist 0.0
# Save image 8742 with dist 0.0
# Save image 8748 with dist 0.0
# Save image 8754 with dist 0.0
# Save image 8760 with dist 0.0
# Save image 8766 with dist 0.0
# Save image 8771 with dist 0.0
# Save image 8777 with dist 0.0
# Save image 8783 with dist 0.0
# Save image 8789 with dist 0.0
# Save image 8795 with dist 0.0
# Save image 8801 with dist 0.0
# Save image 8807 with dist 0.0
# Save image 8812 with dist 0.0
# Save image 8819 with dist 0.0
# Save image 8825 with dist 0.0
# Save image 8832 with dist 0.0
# Save image 8839 with dist 0.0
# Save image 8845 with dist 0.0
# Save image 8852 with dist 0.0
# Save image 8858 with dist 0.0
# Save image 8865 with dist 0.0
# Save image 8871 with dist 0.0
# Save image 8878 with dist 0.0
# Save image 8885 with dist 0.0
# Save image 8892 with dist 0.0
# Save image 8900 with dist 0.0
# Save image 8907 with dist 0.0
# Save image 8914 with dist 0.0
# Save image 8921 with dist 0.0
# Save image 8930 with dist 0.0
# Save image 8937 with dist 0.0
# Save image 8946 with dist 0.0
# Save image 8954 with dist 0.0
# Save image 8962 with dist 0.0
# Save image 8971 with dist 0.0
# Save image 8980 with dist 0.0
# Save image 8989 with dist 0.0
# Save image 8998 with dist 0.0
# Save image 9008 with dist 0.0
# Save image 9028 with dist 0.0
# Save image 9039 with dist 0.0
# Save image 9050 with dist 0.0
# Save image 9062 with dist 0.0
# Save image 9074 with dist 0.0
# Save image 9087 with dist 0.0
# Save image 9102 with dist 0.0
# Save image 9119 with dist 0.0
# Save image 9173 with dist 0.16390594433299596
# Save image 9302 with dist 0.38050105352296376
# Save image 9435 with dist 0.6722507354305342
# Save image 9834 with dist 1.1637239778745232
# Save image 10084 with dist 1.2216223778481134
# Save image 10284 with dist 0.5744315189651857
# Save image 10382 with dist 0.0896292301568534
# Save image 10685 with dist 0.0
# Save image 12132 with dist 0.0
# Save image 12660 with dist 0.0
# Save image 12690 with dist 0.0
# Save image 12716 with dist 0.0
# Save image 12734 with dist 0.0
# Save image 12750 with dist 0.0
# Save image 12766 with dist 0.0
# Save image 12780 with dist 0.0
# Save image 12792 with dist 0.0
# Save image 12805 with dist 0.0
# Save image 12817 with dist 0.0
# Save image 12830 with dist 0.0
# Save image 12841 with dist 0.0
# Save image 12854 with dist 0.0
# Save image 12866 with dist 0.0
# Save image 12879 with dist 0.0
# Save image 12892 with dist 0.0
# Save image 12905 with dist 0.0
# Save image 12919 with dist 0.0
# Save image 12934 with dist 0.0
# Save image 12947 with dist 0.0
# Save image 12962 with dist 0.0
# Save image 12977 with dist 0.0
# Save image 12991 with dist 0.0
# Save image 13008 with dist 0.0
# Save image 13024 with dist 0.0
# Save image 13038 with dist 0.0
# Save image 13052 with dist 0.0
# Save image 13065 with dist 0.0
# Save image 13078 with dist 0.0
# Save image 13090 with dist 0.0
# Save image 13102 with dist 0.0
# Save image 13115 with dist 0.0
# Save image 13127 with dist 0.0
# Save image 13139 with dist 0.0
# Save image 13151 with dist 0.0
# Save image 13162 with dist 0.0
# Save image 13173 with dist 0.0
# Save image 13185 with dist 0.0
# Save image 13197 with dist 0.0
# Save image 13209 with dist 0.0
# Save image 13220 with dist 0.0
# Save image 13232 with dist 0.0
# Save image 13243 with dist 0.0
# Save image 13254 with dist 0.0
# Save image 13265 with dist 0.0
# Save image 13276 with dist 0.0
# Save image 13286 with dist 0.0
# Save image 13298 with dist 0.0
# Save image 13308 with dist 0.0
# Save image 13318 with dist 0.0
# Save image 13328 with dist 0.0
# Save image 13337 with dist 0.0
# Save image 13346 with dist 0.0
# Save image 13355 with dist 0.0
# Save image 13363 with dist 0.0
# Save image 13372 with dist 0.0
# Save image 13381 with dist 0.0
# Save image 13388 with dist 0.0
# Save image 13397 with dist 0.0
# Save image 13404 with dist 0.0
# Save image 13413 with dist 0.0
# Save image 13421 with dist 0.0
# Save image 13429 with dist 0.0
# Save image 13436 with dist 0.0
# Save image 13443 with dist 0.0
# Save image 13451 with dist 0.0
# Save image 13458 with dist 0.0
# Save image 13465 with dist 0.0
# Save image 13473 with dist 0.0
# Save image 13480 with dist 0.0
# Save image 13487 with dist 0.0
# Save image 13494 with dist 0.0
# Save image 13501 with dist 0.0
# Save image 13508 with dist 0.0
# Save image 13515 with dist 0.0
# Save image 13522 with dist 0.0
# Save image 13530 with dist 0.0
# Save image 13537 with dist 0.0
# Save image 13544 with dist 0.0
# Save image 13551 with dist 0.0
# Save image 13558 with dist 0.0
# Save image 13565 with dist 0.0
# Save image 13573 with dist 0.0
# Save image 13580 with dist 0.0
# Save image 13586 with dist 0.0
# Save image 13592 with dist 0.0
# Save image 13599 with dist 0.0
# Save image 13605 with dist 0.0
# Save image 13611 with dist 0.0
# Save image 13617 with dist 0.0
# Save image 13623 with dist 0.0
# Save image 13630 with dist 0.0
# Save image 13636 with dist 0.0
# Save image 13642 with dist 0.0
# Save image 13648 with dist 0.0
# Save image 13654 with dist 0.0
# Save image 13660 with dist 0.0
# Save image 13666 with dist 0.0
# Save image 13672 with dist 0.0
# Save image 13678 with dist 0.0
# Save image 13684 with dist 0.0
# Save image 13691 with dist 0.0
# Save image 13697 with dist 0.0
# Save image 13703 with dist 0.0
# Save image 13709 with dist 0.0
# Save image 13715 with dist 0.0
# Save image 13721 with dist 0.0
# Save image 13727 with dist 0.0
# Save image 13733 with dist 0.0
# Save image 13739 with dist 0.0
# Save image 13745 with dist 0.0
# Save image 13751 with dist 0.0
# Save image 13758 with dist 0.0
# Save image 13764 with dist 0.0
# Save image 13770 with dist 0.0
# Save image 13776 with dist 0.0
# Save image 13782 with dist 0.0
# Save image 13788 with dist 0.0
# Save image 13794 with dist 0.0
# Save image 13800 with dist 0.0
# Save image 13806 with dist 0.0
# Save image 13812 with dist 0.0
# Save image 13818 with dist 0.0
# Save image 13824 with dist 0.0
# Save image 13830 with dist 0.0
# Save image 13836 with dist 0.0
# Save image 13842 with dist 0.0
# Save image 13848 with dist 0.0
# Save image 13854 with dist 0.0
# Save image 13860 with dist 0.0
# Save image 13866 with dist 0.0
# Save image 13873 with dist 0.0
# Save image 13879 with dist 0.0
# Save image 13885 with dist 0.0
# Save image 13891 with dist 0.0
# Save image 13897 with dist 0.0
# Save image 13903 with dist 0.0
# Save image 13909 with dist 0.0
# Save image 13915 with dist 0.0
# Save image 13921 with dist 0.0
# Save image 13927 with dist 0.0
# Save image 13933 with dist 0.0
# Save image 13939 with dist 0.0
# Save image 13945 with dist 0.0
# Save image 13951 with dist 0.0
# Save image 13957 with dist 0.0
# Save image 13963 with dist 0.0
# Save image 13969 with dist 0.0
# Save image 13974 with dist 0.0
# Save image 13980 with dist 0.0
# Save image 13986 with dist 0.0
# Save image 13991 with dist 0.0
# Save image 13997 with dist 0.0
# Save image 14002 with dist 0.0
# Save image 14008 with dist 0.0
# Save image 14014 with dist 0.0
# Save image 14019 with dist 0.0
# Save image 14025 with dist 0.0
# Save image 14031 with dist 0.0
# Save image 14037 with dist 0.0
# Save image 14043 with dist 0.0
# Save image 14049 with dist 0.0
# Save image 14055 with dist 0.0
# Save image 14062 with dist 0.0
# Save image 14068 with dist 0.0
# Save image 14074 with dist 0.0
# Save image 14080 with dist 0.0
# Save image 14086 with dist 0.0
# Save image 14092 with dist 0.0
# Save image 14098 with dist 0.0
# Save image 14105 with dist 0.0
# Save image 14111 with dist 0.0
# Save image 14117 with dist 0.0
# Save image 14123 with dist 0.0
# Save image 14129 with dist 0.0
# Save image 14135 with dist 0.0
# Save image 14141 with dist 0.0
# Save image 14147 with dist 0.0
# Save image 14153 with dist 0.0
# Save image 14159 with dist 0.0
# Save image 14166 with dist 0.0
# Save image 14172 with dist 0.0
# Save image 14178 with dist 0.0
# Save image 14184 with dist 0.0
# Save image 14189 with dist 0.0
# Save image 14196 with dist 0.0
# Save image 14202 with dist 0.0
# Save image 14208 with dist 0.0
# Save image 14214 with dist 0.0
# Save image 14220 with dist 0.0
# Save image 14226 with dist 0.0
# Save image 14232 with dist 0.0
# Save image 14237 with dist 0.0
# Save image 14243 with dist 0.0
# Save image 14249 with dist 0.0
# Save image 14255 with dist 0.0
# Save image 14260 with dist 0.0
# Save image 14266 with dist 0.0
# Save image 14272 with dist 0.0
# Save image 14278 with dist 0.0
# Save image 14284 with dist 0.0
# Save image 14290 with dist 0.0
# Save image 14296 with dist 0.0
# Save image 14302 with dist 0.0
# Save image 14308 with dist 0.0
# Save image 14313 with dist 0.0
# Save image 14319 with dist 0.0
# Save image 14326 with dist 0.0
# Save image 14332 with dist 0.0
# Save image 14337 with dist 0.0
# Save image 14343 with dist 0.0
# Save image 14349 with dist 0.0
# Save image 14355 with dist 0.0
# Save image 14361 with dist 0.0
# Save image 14367 with dist 0.0
# Save image 14373 with dist 0.0
# Save image 14379 with dist 0.0
# Save image 14385 with dist 0.0
# Save image 14390 with dist 0.0
# Save image 14396 with dist 0.0
# Save image 14402 with dist 0.0
# Save image 14407 with dist 0.0
# Save image 14413 with dist 0.0
# Save image 14418 with dist 0.0
# Save image 14423 with dist 0.0
# Save image 14428 with dist 0.0
# Save image 14433 with dist 0.0
# Save image 14438 with dist 0.0
# Save image 14443 with dist 0.0
# Save image 14448 with dist 0.0
# Save image 14453 with dist 0.0
# Save image 14458 with dist 0.0
# Save image 14463 with dist 0.0
# Save image 14468 with dist 0.0
# Save image 14474 with dist 0.0
# Save image 14479 with dist 0.0
# Save image 14484 with dist 0.0
# Save image 14488 with dist 0.0
# Save image 14493 with dist 0.0
# Save image 14498 with dist 0.0
# Save image 14503 with dist 0.0
# Save image 14508 with dist 0.0
# Save image 14514 with dist 0.0
# Save image 14519 with dist 0.0
# Save image 14524 with dist 0.0
# Save image 14529 with dist 0.0
# Save image 14534 with dist 0.0
# Save image 14538 with dist 0.0
# Save image 14543 with dist 0.0
# Save image 14548 with dist 0.0
# Save image 14553 with dist 0.0
# Save image 14559 with dist 0.0
# Save image 14564 with dist 0.0
# Save image 14570 with dist 0.0
# Save image 14576 with dist 0.0
# Save image 14582 with dist 0.0
# Save image 14587 with dist 0.0
# Save image 14593 with dist 0.0
# Save image 14599 with dist 0.0
# Save image 14605 with dist 0.0
# Save image 14611 with dist 0.0
# Save image 14616 with dist 0.0
# Save image 14622 with dist 0.0
# Save image 14628 with dist 0.0
# Save image 14634 with dist 0.0
# Save image 14640 with dist 0.0
# Save image 14646 with dist 0.0
# Save image 14652 with dist 0.0
# Save image 14658 with dist 0.0
# Save image 14664 with dist 0.0
# Save image 14670 with dist 0.0
# Save image 14676 with dist 0.0
# Save image 14681 with dist 0.0
# Save image 14687 with dist 0.0
# Save image 14693 with dist 0.0
# Save image 14699 with dist 0.0
# Save image 14705 with dist 0.0
# Save image 14711 with dist 0.0
# Save image 14717 with dist 0.0
# Save image 14723 with dist 0.0
# Save image 14729 with dist 0.0
# Save image 14734 with dist 0.0
# Save image 14740 with dist 0.0
# Save image 14746 with dist 0.0
# Save image 14752 with dist 0.0
# Save image 14758 with dist 0.0
# Save image 14764 with dist 0.0
# Save image 14770 with dist 0.0
# Save image 14776 with dist 0.0
# Save image 14781 with dist 0.0
# Save image 14787 with dist 0.0
# Save image 14793 with dist 0.0
# Save image 14799 with dist 0.0
# Save image 14805 with dist 0.0
# Save image 14811 with dist 0.0
# Save image 14816 with dist 0.0
# Save image 14822 with dist 0.0
# Save image 14828 with dist 0.0
# Save image 14834 with dist 0.0
# Save image 14841 with dist 0.0
# Save image 14848 with dist 0.0
# Save image 14854 with dist 0.0
# Save image 14861 with dist 0.0
# Save image 14868 with dist 0.0
# Save image 14875 with dist 0.0
# Save image 14882 with dist 0.0
# Save image 14888 with dist 0.0
# Save image 14895 with dist 0.0
# Save image 14902 with dist 0.0
# Save image 14909 with dist 0.0
# Save image 14916 with dist 0.0
# Save image 14923 with dist 0.0
# Save image 14929 with dist 0.0
# Save image 14936 with dist 0.0
# Save image 14943 with dist 0.0
# Save image 14950 with dist 0.0
# Save image 14957 with dist 0.0
# Save image 14964 with dist 0.0
# Save image 14971 with dist 0.0
# Save image 14978 with dist 0.0
# Save image 14986 with dist 0.0
# Save image 14993 with dist 0.0
# Save image 15001 with dist 0.0
# Save image 15008 with dist 0.0
# Save image 15016 with dist 0.0
# Save image 15023 with dist 0.0
# Save image 15031 with dist 0.0
# Save image 15038 with dist 0.0
# Save image 15047 with dist 0.0
# Save image 15055 with dist 0.0
# Save image 15064 with dist 0.0
# Save image 15073 with dist 0.0
# Save image 15082 with dist 0.0
# Save image 15089 with dist 0.0
# Save image 15098 with dist 0.0
# Save image 15108 with dist 0.0
# Save image 15120 with dist 0.0
# Save image 15131 with dist 0.0
# Save image 15141 with dist 0.0
# Save image 15156 with dist 0.0
# Save image 15172 with dist 0.0
# Save image 15189 with dist 0.0
# Save image 15217 with dist 0.0
# Save image 15287 with dist 0.0
# Save image 15384 with dist 0.0
# Save image 15413 with dist 0.0
# Save image 15435 with dist 0.0
# Save image 15451 with dist 0.0
# Save image 15466 with dist 0.0
# Save image 15480 with dist 0.0
# Save image 15491 with dist 0.0
# Save image 15503 with dist 0.0
# Save image 15513 with dist 0.0
# Save image 15524 with dist 0.0
# Save image 15534 with dist 0.0
# Save image 15543 with dist 0.0
# Save image 15551 with dist 0.0
# Save image 15560 with dist 0.0
# Save image 15569 with dist 0.0
# Save image 15578 with dist 0.0
# Save image 15585 with dist 0.0
# Save image 15594 with dist 0.0
# Save image 15602 with dist 0.0
# Save image 15611 with dist 0.0
# Save image 15619 with dist 0.0
# Save image 15627 with dist 0.0
# Save image 15636 with dist 0.0
# Save image 15644 with dist 0.0
# Save image 15651 with dist 0.0
# Save image 15659 with dist 0.0
# Save image 15667 with dist 0.0
# Save image 15675 with dist 0.0
# Save image 15683 with dist 0.0
# Save image 15691 with dist 0.0
# Save image 15698 with dist 0.0
# Save image 15705 with dist 0.0
# Save image 15713 with dist 0.0
# Save image 15721 with dist 0.0
# Save image 15729 with dist 0.0
# Save image 15736 with dist 0.0
# Save image 15744 with dist 0.0
# Save image 15752 with dist 0.0
# Save image 15759 with dist 0.0
# Save image 15767 with dist 0.0
# Save image 15775 with dist 0.0
# Save image 15783 with dist 0.0
# Save image 15792 with dist 0.0
# Save image 15800 with dist 0.0
# Save image 15809 with dist 0.0
# Save image 15817 with dist 0.0
# Save image 15825 with dist 0.0
# Save image 15834 with dist 0.0
# Save image 15843 with dist 0.0
# Save image 15852 with dist 0.0
# Save image 15861 with dist 0.0
# Save image 15870 with dist 0.0
# Save image 15880 with dist 0.0
# Save image 15890 with dist 0.0
# Save image 15900 with dist 0.0
# Save image 15910 with dist 0.0
# Save image 15921 with dist 0.0
# Save image 15932 with dist 0.0
# Save image 15942 with dist 0.0
# Save image 15953 with dist 0.0
# Save image 15964 with dist 0.0
# Save image 15975 with dist 0.0
# Save image 15985 with dist 0.0
# Save image 15995 with dist 0.0
# Save image 16006 with dist 0.0
# Save image 16016 with dist 0.0
# Save image 16026 with dist 0.0
# Save image 16035 with dist 0.0
# Save image 16045 with dist 0.0
# Save image 16054 with dist 0.0
# Save image 16064 with dist 0.0
# Save image 16073 with dist 0.0
# Save image 16082 with dist 0.0
# Save image 16090 with dist 0.0
# Save image 16100 with dist 0.0
# Save image 16110 with dist 0.0
# Save image 16119 with dist 0.0
# Save image 16128 with dist 0.0
# Save image 16137 with dist 0.0
# Save image 16146 with dist 0.0
# Save image 16156 with dist 0.0
# Save image 16165 with dist 0.0
# Save image 16174 with dist 0.0
# Save image 16184 with dist 0.0
# Save image 16193 with dist 0.0
# Save image 16203 with dist 0.0
# Save image 16212 with dist 0.0
# Save image 16221 with dist 0.0
# Save image 16229 with dist 0.0
# Save image 16238 with dist 0.0
# Save image 16246 with dist 0.0
# Save image 16254 with dist 0.0
# Save image 16263 with dist 0.0
# Save image 16271 with dist 0.0
# Save image 16279 with dist 0.0
# Save image 16287 with dist 0.0
# Save image 16295 with dist 0.0
# Save image 16303 with dist 0.0
# Save image 16311 with dist 0.0
# Save image 16318 with dist 0.0
# Save image 16327 with dist 0.0
# Save image 16335 with dist 0.0
# Save image 16343 with dist 0.0
# Save image 16351 with dist 0.0
# Save image 16359 with dist 0.0
# Save image 16367 with dist 0.0
# Save image 16375 with dist 0.0
# Save image 16383 with dist 0.0
# Save image 16392 with dist 0.0
# Save image 16401 with dist 0.0
# Save image 16409 with dist 0.0
# Save image 16418 with dist 0.0
# Save image 16427 with dist 0.0
# Save image 16435 with dist 0.0
# Save image 16443 with dist 0.0
# Save image 16452 with dist 0.0
# Save image 16461 with dist 0.0
# Save image 16470 with dist 0.0
# Save image 16478 with dist 0.0
# Save image 16487 with dist 0.0
# Save image 16496 with dist 0.0
# Save image 16505 with dist 0.0
# Save image 16514 with dist 0.0
# Save image 16523 with dist 0.0
# Save image 16532 with dist 0.0
# Save image 16540 with dist 0.0
# Save image 16549 with dist 0.0
# Save image 16558 with dist 0.0
# Save image 16567 with dist 0.0
# Save image 16576 with dist 0.0
# Save image 16584 with dist 0.0
# Save image 16595 with dist 0.0
# Save image 16604 with dist 0.0
# Save image 16613 with dist 0.0
# Save image 16623 with dist 0.0
# Save image 16631 with dist 0.0
# Save image 16637 with dist 0.0
# Save image 16645 with dist 0.0
# Save image 16654 with dist 0.0
# Save image 16662 with dist 0.0
# Save image 16671 with dist 0.0
# Save image 16679 with dist 0.0
# Save image 16687 with dist 0.0
# Save image 16696 with dist 0.0
# Save image 16704 with dist 0.0
# Save image 16712 with dist 0.0
# Save image 16719 with dist 0.0
# Save image 16727 with dist 0.0
# Save image 16734 with dist 0.0
# Save image 16741 with dist 0.0
# Save image 16749 with dist 0.0
# Save image 16756 with dist 0.0
# Save image 16763 with dist 0.0
# Save image 16770 with dist 0.0
# Save image 16777 with dist 0.0
# Save image 16785 with dist 0.0
# Save image 16792 with dist 0.0
# Save image 16799 with dist 0.0
# Save image 16806 with dist 0.0
# Save image 16813 with dist 0.0
# Save image 16820 with dist 0.0
# Save image 16827 with dist 0.0
# Save image 16834 with dist 0.0
# Save image 16841 with dist 0.0
# Save image 16848 with dist 0.0
# Save image 16856 with dist 0.0
# Save image 16863 with dist 0.0
# Save image 16870 with dist 0.0
# Save image 16877 with dist 0.0
# Save image 16883 with dist 0.0
# Save image 16890 with dist 0.0
# Save image 16897 with dist 0.0
# Save image 16904 with dist 0.0
# Save image 16911 with dist 0.0
# Save image 16919 with dist 0.0
# Save image 16926 with dist 0.0
# Save image 16933 with dist 0.0
# Save image 16940 with dist 0.0
# Save image 16947 with dist 0.0
# Save image 16955 with dist 0.0
# Save image 16962 with dist 0.0
# Save image 16969 with dist 0.0
# Save image 16976 with dist 0.0
# Save image 16983 with dist 0.0
# Save image 16987 with dist 0.0
# Save image 16994 with dist 0.0
# Save image 17001 with dist 0.0
# Save image 17008 with dist 0.0
# Save image 17014 with dist 0.0
# Save image 17021 with dist 0.0
# Save image 17028 with dist 0.0
# Save image 17035 with dist 0.0
# Save image 17042 with dist 0.0
# Save image 17049 with dist 0.0
# Save image 17056 with dist 0.0
# Save image 17063 with dist 0.0
# Save image 17069 with dist 0.0
# Save image 17076 with dist 0.0
# Save image 17081 with dist 0.0
# Save image 17088 with dist 0.0
# Save image 17096 with dist 0.0
# Save image 17104 with dist 0.0
# Save image 17111 with dist 0.0
# Save image 17119 with dist 0.0
# Save image 17127 with dist 0.0
# Save image 17135 with dist 0.0
# Save image 17142 with dist 0.0
# Save image 17150 with dist 0.0
# Save image 17158 with dist 0.0
# Save image 17166 with dist 0.0
# Save image 17173 with dist 0.0
# Save image 17181 with dist 0.0
# Save image 17186 with dist 0.0
# Save image 17194 with dist 0.0
# Save image 17202 with dist 0.0
# Save image 17210 with dist 0.0
# Save image 17218 with dist 0.0
# Save image 17226 with dist 0.0
# Save image 17236 with dist 0.0
# Save image 17244 with dist 0.0
# Save image 17253 with dist 0.0
# Save image 17263 with dist 0.0
# Save image 17273 with dist 0.0
# Save image 17289 with dist 0.0
# Save image 17299 with dist 0.0
# Save image 17310 with dist 0.0
# Save image 17321 with dist 0.0
# Save image 17330 with dist 0.0
# Save image 17336 with dist 0.0
# Save image 17347 with dist 0.0
# Save image 17358 with dist 0.0
# Save image 17370 with dist 0.0
# Save image 17381 with dist 0.0
# Save image 17386 with dist 0.0
# Save image 17398 with dist 0.0
# Save image 17409 with dist 0.0
# Save image 17419 with dist 0.0
# Save image 17430 with dist 0.0
# Save image 17438 with dist 0.0
# Save image 17448 with dist 0.0
# Save image 17458 with dist 0.0
# Save image 17466 with dist 0.0
# Save image 17474 with dist 0.0
# Save image 17482 with dist 0.0
# Save image 17489 with dist 0.0
# Save image 17497 with dist 0.0
# Save image 17504 with dist 0.0
# Save image 17511 with dist 0.0
# Save image 17518 with dist 0.0
# Save image 17525 with dist 0.0
# Save image 17531 with dist 0.0
# Save image 17537 with dist 0.0
# Save image 17544 with dist 0.0
# Save image 17550 with dist 0.0
# Save image 17557 with dist 0.0
# Save image 17563 with dist 0.0
# Save image 17569 with dist 0.0
# Save image 17576 with dist 0.0
# Save image 17582 with dist 0.0
# Save image 17588 with dist 0.0
# Save image 17594 with dist 0.0
# Save image 17600 with dist 0.0
# Save image 17607 with dist 0.0
# Save image 17613 with dist 0.0
# Save image 17619 with dist 0.0
# Save image 17625 with dist 0.0
# Save image 17631 with dist 0.0
# Save image 17637 with dist 0.0
# Save image 17643 with dist 0.0
# Save image 17649 with dist 0.0
# Save image 17655 with dist 0.0
# Save image 17660 with dist 0.0
# Save image 17667 with dist 0.0
# Save image 17673 with dist 0.0
# Save image 17679 with dist 0.0
# Save image 17684 with dist 0.0
# Save image 17690 with dist 0.0
# Save image 17696 with dist 0.0
# Save image 17702 with dist 0.0
# Save image 17708 with dist 0.0
# Save image 17714 with dist 0.0
# Save image 17720 with dist 0.0
# Save image 17726 with dist 0.0
# Save image 17732 with dist 0.0
# Save image 17737 with dist 0.0
# Save image 17743 with dist 0.0
# Save image 17749 with dist 0.0
# Save image 17755 with dist 0.0
# Save image 17761 with dist 0.0
# Save image 17767 with dist 0.0
# Save image 17773 with dist 0.0
# Save image 17779 with dist 0.0
# Save image 17785 with dist 0.0
# Save image 17790 with dist 0.0
# Save image 17796 with dist 0.0
# Save image 17802 with dist 0.0
# Save image 17808 with dist 0.0
# Save image 17814 with dist 0.0
# Save image 17820 with dist 0.0
# Save image 17826 with dist 0.0
# Save image 17831 with dist 0.0
# Save image 17835 with dist 0.0
# Save image 17840 with dist 0.0
# Save image 17845 with dist 0.0
# Save image 17850 with dist 0.0
# Save image 17855 with dist 0.0
# Save image 17860 with dist 0.0
# Save image 17865 with dist 0.0
# Save image 17870 with dist 0.0
# Save image 17875 with dist 0.0
# Save image 17880 with dist 0.0
# Save image 17885 with dist 0.0
# Save image 17890 with dist 0.0
# Save image 17895 with dist 0.0
# Save image 17900 with dist 0.0
# Save image 17905 with dist 0.0
# Save image 17910 with dist 0.0
# Save image 17915 with dist 0.0
# Save image 17920 with dist 0.0
# Save image 17925 with dist 0.0
# Save image 17931 with dist 0.0
# Save image 17935 with dist 0.0
# Save image 17940 with dist 0.0
# Save image 17945 with dist 0.0
# Save image 17950 with dist 0.0
# Save image 17955 with dist 0.0
# Save image 17960 with dist 0.0
# Save image 17965 with dist 0.0
# Save image 17970 with dist 0.0
# Save image 17975 with dist 0.0
# Save image 17980 with dist 0.0
# Save image 17985 with dist 0.0
# Save image 17990 with dist 0.0
# Save image 17995 with dist 0.0
# Save image 18000 with dist 0.0
# Save image 18005 with dist 0.0
# Save image 18010 with dist 0.0
# Save image 18015 with dist 0.0
# Save image 18020 with dist 0.0
# Save image 18025 with dist 0.0
# Save image 18030 with dist 0.0
# Save image 18035 with dist 0.0
# Save image 18040 with dist 0.0
# Save image 18045 with dist 0.0
# Save image 18050 with dist 0.0
# Save image 18055 with dist 0.0
# Save image 18060 with dist 0.0
# Save image 18065 with dist 0.0
# Save image 18070 with dist 0.0
# Save image 18075 with dist 0.0
# Save image 18080 with dist 0.0
# Save image 18085 with dist 0.0
# Save image 18090 with dist 0.0
# Save image 18095 with dist 0.0
# Save image 18100 with dist 0.0
# Save image 18105 with dist 0.0
# Save image 18110 with dist 0.0
# Save image 18115 with dist 0.0
# Save image 18120 with dist 0.0
# Save image 18125 with dist 0.0
# Save image 18130 with dist 0.0
# Save image 18135 with dist 0.0
# Save image 18140 with dist 0.0
# Save image 18145 with dist 0.0
# Save image 18150 with dist 0.0
# Save image 18155 with dist 0.0
# Save image 18160 with dist 0.0
# Save image 18165 with dist 0.0
# Save image 18170 with dist 0.0
# Save image 18175 with dist 0.0
# Save image 18180 with dist 0.0
# Save image 18185 with dist 0.0
# Save image 18190 with dist 0.0
# Save image 18195 with dist 0.0
# Save image 18200 with dist 0.0
# Save image 18205 with dist 0.0
# Save image 18210 with dist 0.0
# Save image 18215 with dist 0.0
# Save image 18220 with dist 0.0
# Save image 18225 with dist 0.0
# Save image 18230 with dist 0.0
# Save image 18235 with dist 0.0
# Save image 18240 with dist 0.0
# Save image 18245 with dist 0.0
# Save image 18250 with dist 0.0
# Save image 18255 with dist 0.0
# Save image 18260 with dist 0.0
# Save image 18265 with dist 0.0
# Save image 18271 with dist 0.0
# Save image 18277 with dist 0.0
# Save image 18283 with dist 0.0
# Save image 18288 with dist 0.0
# Save image 18294 with dist 0.0
# Save image 18300 with dist 0.0
# Save image 18306 with dist 0.0
# Save image 18311 with dist 0.0
# Save image 18317 with dist 0.0
# Save image 18323 with dist 0.0
# Save image 18329 with dist 0.0
# Save image 18335 with dist 0.0
# Save image 18340 with dist 0.0
# Save image 18346 with dist 0.0
# Save image 18352 with dist 0.0
# Save image 18358 with dist 0.0
# Save image 18364 with dist 0.0
# Save image 18370 with dist 0.0
# Save image 18376 with dist 0.0
# Save image 18382 with dist 0.0
# Save image 18388 with dist 0.0
# Save image 18393 with dist 0.0
# Save image 18399 with dist 0.0
# Save image 18405 with dist 0.0
# Save image 18410 with dist 0.0
# Save image 18416 with dist 0.0
# Save image 18422 with dist 0.0
# Save image 18427 with dist 0.0
# Save image 18434 with dist 0.0
# Save image 18441 with dist 0.0
# Save image 18447 with dist 0.0
# Save image 18454 with dist 0.0
# Save image 18460 with dist 0.0
# Save image 18467 with dist 0.0
# Save image 18473 with dist 0.0
# Save image 18480 with dist 0.0
# Save image 18486 with dist 0.0
# Save image 18493 with dist 0.0
# Save image 18500 with dist 0.0
# Save image 18508 with dist 0.0
# Save image 18515 with dist 0.0
# Save image 18522 with dist 0.0
# Save image 18530 with dist 0.0
# Save image 18538 with dist 0.0
# Save image 18545 with dist 0.0
# Save image 18553 with dist 0.0
# Save image 18561 with dist 0.0
# Save image 18570 with dist 0.0
# Save image 18580 with dist 0.0
# Save image 18589 with dist 0.0
# Save image 18599 with dist 0.0
# Save image 18609 with dist 0.0
# Save image 18618 with dist 0.0
# Save image 18628 with dist 0.0
# Save image 18638 with dist 0.0
# Save image 18647 with dist 0.0
# Save image 18657 with dist 0.0
# Save image 18667 with dist 0.0
# Save image 18677 with dist 0.0
# Save image 18686 with dist 0.0
# Save image 18696 with dist 0.0
# Save image 18706 with dist 0.0
# Save image 18716 with dist 0.0
# Save image 18726 with dist 0.0
# Save image 18736 with dist 0.0
# Save image 18746 with dist 0.0
# Save image 18756 with dist 0.0
# Save image 18766 with dist 0.0
# Save image 18776 with dist 0.0
# Save image 18786 with dist 0.0
# Save image 18797 with dist 0.0
# Save image 18807 with dist 0.0
# Save image 18818 with dist 0.0
# Save image 18829 with dist 0.0
# Save image 18839 with dist 0.0
# Save image 18849 with dist 0.0
# Save image 18860 with dist 0.0
# Save image 18870 with dist 0.0
# Save image 18881 with dist 0.0
# Save image 18891 with dist 0.0
# Save image 18901 with dist 0.0
# Save image 18911 with dist 0.0
# Save image 18921 with dist 0.0
# Save image 18931 with dist 0.0
# Save image 18940 with dist 0.0
# Save image 18950 with dist 0.0
# Save image 18958 with dist 0.0
# Save image 18967 with dist 0.0
# Save image 18976 with dist 0.0
# Save image 18985 with dist 0.0
# Save image 18994 with dist 0.0
# Save image 19002 with dist 0.0
# Save image 19010 with dist 0.0
# Save image 19017 with dist 0.0
# Save image 19025 with dist 0.0
# Save image 19032 with dist 0.0
# Save image 19039 with dist 0.0
# Save image 19046 with dist 0.0
# Save image 19054 with dist 0.0
# Save image 19061 with dist 0.0
# Save image 19069 with dist 0.0
# Save image 19076 with dist 0.0
# Save image 19083 with dist 0.0
# Save image 19090 with dist 0.0
# Save image 19097 with dist 0.0
# Save image 19104 with dist 0.0
# Save image 19111 with dist 0.0
# Save image 19118 with dist 0.0
# Save image 19125 with dist 0.0
# Save image 19132 with dist 0.0
# Save image 19140 with dist 0.0
# Save image 19147 with dist 0.0
# Save image 19154 with dist 0.0
# Save image 19161 with dist 0.0
# Save image 19168 with dist 0.0
# Save image 19175 with dist 0.0
# Save image 19182 with dist 0.0
# Save image 19190 with dist 0.0
# Save image 19196 with dist 0.0
# Save image 19203 with dist 0.0
# Save image 19210 with dist 0.0
# Save image 19217 with dist 0.0
# Save image 19224 with dist 0.0
# Save image 19231 with dist 0.0
# Save image 19238 with dist 0.0
# Save image 19245 with dist 0.0
# Save image 19252 with dist 0.0
# Save image 19259 with dist 0.0
# Save image 19266 with dist 0.0
# Save image 19272 with dist 0.0
# Save image 19279 with dist 0.0
# Save image 19286 with dist 0.0
# Save image 19293 with dist 0.0
# Save image 19300 with dist 0.0
# Save image 19307 with dist 0.0
# Save image 19314 with dist 0.0
# Save image 19321 with dist 0.0
# Save image 19328 with dist 0.0
# Save image 19335 with dist 0.0
# Save image 19341 with dist 0.0
# Save image 19348 with dist 0.0
# Save image 19355 with dist 0.0
# Save image 19363 with dist 0.0
# Save image 19371 with dist 0.0
# Save image 19378 with dist 0.0
# Save image 19386 with dist 0.0
# Save image 19393 with dist 0.0
# Save image 19400 with dist 0.0
# Save image 19408 with dist 0.0
# Save image 19415 with dist 0.0
# Save image 19423 with dist 0.0
# Save image 19431 with dist 0.0
# Save image 19438 with dist 0.0
# Save image 19447 with dist 0.0
# Save image 19456 with dist 0.0
# Save image 19464 with dist 0.0
# Save image 19473 with dist 0.0
# Save image 19481 with dist 0.0
# Save image 19490 with dist 0.0
# Save image 19499 with dist 0.0
# Save image 19507 with dist 0.0
# Save image 19516 with dist 0.0
# Save image 19524 with dist 0.0
# Save image 19533 with dist 0.0
# Save image 19542 with dist 0.0
# Save image 19551 with dist 0.0
# Save image 19560 with dist 0.0
# Save image 19569 with dist 0.0
# Save image 19578 with dist 0.0
# Save image 19588 with dist 0.0
# Save image 19598 with dist 0.0
# Save image 19608 with dist 0.0
# Save image 19618 with dist 0.0
# Save image 19629 with dist 0.0
# Save image 19640 with dist 0.0
# Save image 19652 with dist 0.0
# Save image 19665 with dist 0.0
# Save image 19678 with dist 0.0
# Save image 19692 with dist 0.0
# Save image 19709 with dist 0.0
# Save image 19729 with dist 0.0
# Save image 19750 with dist 0.0
# Save image 19783 with dist 0.0
# Save image 19823 with dist 0.0
# Save image 19881 with dist 0.0
# Save image 19918 with dist 0.0
# Save image 19939 with dist 0.0
# Save image 19958 with dist 0.0
# Save image 19973 with dist 0.0
# Save image 19986 with dist 0.0
# Save image 19998 with dist 0.0
# Save image 20009 with dist 0.0
# Save image 20019 with dist 0.0
# Save image 20030 with dist 0.0
# Save image 20040 with dist 0.0
# Save image 20050 with dist 0.0
# Save image 20059 with dist 0.0
# Save image 20070 with dist 0.0
# Save image 20080 with dist 0.0
# Save image 20091 with dist 0.0
# Save image 20101 with dist 0.0
# Save image 20111 with dist 0.0
# Save image 20121 with dist 0.0
# Save image 20132 with dist 0.0
# Save image 20143 with dist 0.0
# Save image 20154 with dist 0.0
# Save image 20165 with dist 0.0
# Save image 20176 with dist 0.0
# Save image 20186 with dist 0.0
# Save image 20198 with dist 0.0
# Save image 20210 with dist 0.0
# Save image 20223 with dist 0.0
# Save image 20237 with dist 0.0
# Save image 20252 with dist 0.0
# Save image 20270 with dist 0.0
# Save image 20289 with dist 0.0
# Save image 20315 with dist 0.0
# Save image 20340 with dist 0.0
# Save image 20369 with dist 0.0
# Save image 20391 with dist 0.0
# Save image 20411 with dist 0.0
# Save image 20427 with dist 0.0
# Save image 20440 with dist 0.0
# Save image 20453 with dist 0.0
# Save image 20465 with dist 0.0
# Save image 20477 with dist 0.0
# Save image 20487 with dist 0.0
# Save image 20498 with dist 0.0
# Save image 20507 with dist 0.0
# Save image 20517 with dist 0.0
# Save image 20526 with dist 0.0
# Save image 20535 with dist 0.0
# Save image 20543 with dist 0.0
# Save image 20551 with dist 0.0
# Save image 20559 with dist 0.0
# Save image 20567 with dist 0.0
# Save image 20574 with dist 0.0
# Save image 20582 with dist 0.0
# Save image 20589 with dist 0.0
# Save image 20596 with dist 0.0
# Save image 20603 with dist 0.0
# Save image 20610 with dist 0.0
# Save image 20617 with dist 0.0
# Save image 20625 with dist 0.0
# Save image 20632 with dist 0.0
# Save image 20638 with dist 0.0
# Save image 20645 with dist 0.0
# Save image 20652 with dist 0.0
# Save image 20659 with dist 0.0
# Save image 20666 with dist 0.0
# Save image 20673 with dist 0.0
# Save image 20680 with dist 0.0
# Save image 20686 with dist 0.0
# Save image 20693 with dist 0.0
# Save image 20699 with dist 0.0
# Save image 20707 with dist 0.0
# Save image 20713 with dist 0.0
# Save image 20720 with dist 0.0
# Save image 20727 with dist 0.0
# Save image 20734 with dist 0.0
# Save image 20741 with dist 0.0
# Save image 20748 with dist 0.0
# Save image 20755 with dist 0.0
# Save image 20762 with dist 0.0
# Save image 20769 with dist 0.0
# Save image 20776 with dist 0.0
# Save image 20783 with dist 0.0
# Save image 20789 with dist 0.0
# Save image 20796 with dist 0.0
# Save image 20803 with dist 0.0
# Save image 20810 with dist 0.0
# Save image 20817 with dist 0.0
# Save image 20824 with dist 0.0
# Save image 20831 with dist 0.0
# Save image 20838 with dist 0.0
# Save image 20845 with dist 0.0
# Save image 20852 with dist 0.0
# Save image 20858 with dist 0.0
# Save image 20865 with dist 0.0
# Save image 20872 with dist 0.0
# Save image 20879 with dist 0.0
# Save image 20885 with dist 0.0
# Save image 20892 with dist 0.0
# Save image 20899 with dist 0.0
# Save image 20906 with dist 0.0
# Save image 20912 with dist 0.0
# Save image 20919 with dist 0.0
# Save image 20926 with dist 0.0
# Save image 20933 with dist 0.0
# Save image 20939 with dist 0.0
# Save image 20947 with dist 0.0
# Save image 20954 with dist 0.0
# Save image 20961 with dist 0.0
# Save image 20969 with dist 0.0
# Save image 20977 with dist 0.0
# Save image 20984 with dist 0.0
# Save image 20992 with dist 0.0
# Save image 20999 with dist 0.0
# Save image 21007 with dist 0.0
# Save image 21015 with dist 0.0
# Save image 21022 with dist 0.0
# Save image 21030 with dist 0.0
# Save image 21037 with dist 0.0
# Save image 21045 with dist 0.0
# Save image 21053 with dist 0.0
# Save image 21061 with dist 0.0
# Save image 21070 with dist 0.0
# Save image 21078 with dist 0.0
# Save image 21086 with dist 0.0
# Save image 21095 with dist 0.0
# Save image 21103 with dist 0.0
# Save image 21112 with dist 0.0
# Save image 21120 with dist 0.0
# Save image 21129 with dist 0.0
# Save image 21138 with dist 0.0
# Save image 21147 with dist 0.0
# Save image 21156 with dist 0.0
# Save image 21166 with dist 0.0
# Save image 21175 with dist 0.0
# Save image 21184 with dist 0.0
# Save image 21194 with dist 0.0
# Save image 21203 with dist 0.0
# Save image 21213 with dist 0.0
# Save image 21223 with dist 0.0
# Save image 21233 with dist 0.0
# Save image 21242 with dist 0.0
# Save image 21253 with dist 0.0
# Save image 21263 with dist 0.0
# Save image 21273 with dist 0.0
# Save image 21284 with dist 0.0
# Save image 21294 with dist 0.0
# Save image 21304 with dist 0.0
# Save image 21315 with dist 0.0
# Save image 21326 with dist 0.0
# Save image 21337 with dist 0.0
# Save image 21350 with dist 0.0
# Save image 21364 with dist 0.0
# Save image 21380 with dist 0.0
# Save image 21398 with dist 0.0
# Save image 21420 with dist 0.0
# Save image 21444 with dist 0.0
# Save image 21479 with dist 0.0
# Save image 21518 with dist 0.0
# Save image 21562 with dist 0.0
# Save image 21617 with dist 0.0
# Save image 21685 with dist 0.0
# Save image 21763 with dist 0.0
# Save image 21850 with dist 0.0
# Save image 21962 with dist 0.0
# Save image 22111 with dist 0.0
# Save image 22312 with dist 0.0
# Save image 22394 with dist 0.0
# Save image 22428 with dist 0.0
# Save image 22449 with dist 0.0
# Save image 22467 with dist 0.0
# Save image 22483 with dist 0.0
# Save image 22495 with dist 0.0
# Save image 22509 with dist 0.0
# Save image 22521 with dist 0.0
# Save image 22533 with dist 0.0
# Save image 22543 with dist 0.0
# Save image 22555 with dist 0.0
# Save image 22565 with dist 0.0
# Save image 22575 with dist 0.0
# Save image 22585 with dist 0.0
# Save image 22595 with dist 0.0
# Save image 22604 with dist 0.0
# Save image 22614 with dist 0.0
# Save image 22623 with dist 0.0
# Save image 22632 with dist 0.0
# Save image 22641 with dist 0.0
# Save image 22649 with dist 0.0
# Save image 22659 with dist 0.0
# Save image 22668 with dist 0.0
# Save image 22677 with dist 0.0
# Save image 22686 with dist 0.0
# Save image 22695 with dist 0.0
# Save image 22704 with dist 0.0
# Save image 22712 with dist 0.0
# Save image 22721 with dist 0.0
# Save image 22729 with dist 0.0
# Save image 22737 with dist 0.0
# Save image 22745 with dist 0.0
# Save image 22753 with dist 0.0
# Save image 22761 with dist 0.0
# Save image 22769 with dist 0.0
# Save image 22777 with dist 0.0
# Save image 22785 with dist 0.0
# Save image 22794 with dist 0.0
# Save image 22802 with dist 0.0
# Save image 22810 with dist 0.0
# Save image 22819 with dist 0.0
# Save image 22827 with dist 0.0
# Save image 22836 with dist 0.0
# Save image 22844 with dist 0.0
# Save image 22852 with dist 0.0
# Save image 22860 with dist 0.0
# Save image 22868 with dist 0.0
# Save image 22876 with dist 0.0
# Save image 22884 with dist 0.0
# Save image 22892 with dist 0.0
# Save image 22899 with dist 0.0
# Save image 22907 with dist 0.0
# Save image 22915 with dist 0.0
# Save image 22923 with dist 0.0
# Save image 22930 with dist 0.0
# Save image 22937 with dist 0.0
# Save image 22944 with dist 0.0
# Save image 22952 with dist 0.0
# Save image 22959 with dist 0.0
# Save image 22966 with dist 0.0
# Save image 22973 with dist 0.0
# Save image 22981 with dist 0.0
# Save image 22988 with dist 0.0
# Save image 22996 with dist 0.0
# Save image 23004 with dist 0.0
# Save image 23012 with dist 0.0
# Save image 23020 with dist 0.0
# Save image 23028 with dist 0.0
# Save image 23036 with dist 0.0
# Save image 23044 with dist 0.0
# Save image 23052 with dist 0.0
# Save image 23060 with dist 0.0
# Save image 23068 with dist 0.0
# Save image 23075 with dist 0.0
# Save image 23083 with dist 0.0
# Save image 23090 with dist 0.0
# Save image 23099 with dist 0.0
# Save image 23106 with dist 0.0
# Save image 23114 with dist 0.0
# Save image 23122 with dist 0.0
# Save image 23130 with dist 0.0
# Save image 23137 with dist 0.0
# Save image 23145 with dist 0.0
# Save image 23153 with dist 0.0
# Save image 23161 with dist 0.0
# Save image 23168 with dist 0.0
# Save image 23176 with dist 0.0
# Save image 23184 with dist 0.0
# Save image 23191 with dist 0.0
# Save image 23200 with dist 0.0
# Save image 23208 with dist 0.0
# Save image 23215 with dist 0.0
# Save image 23224 with dist 0.0
# Save image 23233 with dist 0.0
# Save image 23241 with dist 0.0
# Save image 23250 with dist 0.0
# Save image 23258 with dist 0.0
# Save image 23267 with dist 0.0
# Save image 23276 with dist 0.0
# Save image 23285 with dist 0.0
# Save image 23292 with dist 0.0
# --------------------------------------------------------
# IndexError             Traceback (most recent call last)
# <ipython-input-5-4f55c591fb75> in <module>
#       5 img_loader = ImageLoader(camera_type, center_offset=offset)
#       6 img_loader.load_ned_trajectory(subset_split=0.2)
# ----> 7 img_loader.load_images(submap_length)
#
# <ipython-input-4-e2d9f9fb0f08> in load_images(self, submap_length)
#     173                 # Set new reference position
#     174                 i_pcl += 1
# --> 175                 ref_pos = np.array([pcl_metadata[i_pcl]['northing_'+ref],
#     176                                     pcl_metadata[i_pcl]['easting_'+ref]])
#     177                 dist_min = 1.0e9
#
# IndexError: list index out of range
