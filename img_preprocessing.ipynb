# %%
# First time
# %cd /content
# !git clone https://github.com/FireMight/point-cloud-retrieval-from-image.git
# %cd /content/point-cloud-retrieval-from-image
# !git submodule update --init --recursive
# %cd ..

# %%
# Pull repository
# %cd /content/point-cloud-retrieval-from-image
# !git pull --recurse-submodules
# %cd ..

# %%
import csv
import os
import sys
import math
import numpy as np
from datetime import datetime
from PIL import Image

# %%
# For Google colab
from google.colab import drive
drive.mount('/content/drive')

sdk_dir = '/content/point-cloud-retrieval-from-image/data/oxford/robotcar-dataset-sdk'
project_dir = '/content/drive/My Drive/ADL4CV'

run_id = 'reference'
data_dir = project_dir + '/downloads/oxford_dataset/' + run_id
gps_dir = data_dir + '/gps'
ins_data_file = gps_dir + '/ins.csv'
extrinsics_dir = sdk_dir + '/extrinsics'

# %%
# For local use
sdk_dir = 'data/oxford/robotcar-dataset-sdk'

run_id = 'reference'
data_dir = 'data/oxford/data/'  + run_id
gps_dir = data_dir + '/gps'
ins_data_file = gps_dir + '/ins.csv'
extrinsics_dir = sdk_dir + '/extrinsics'

# %%
def read_metadata_csv_row(row):
    metadata = {}
    metadata['seg_idx'] = int(row['seg_idx'])
    metadata['timestamp_start'] = int(row['timestamp_start'])
    metadata['northing_start'] = float(row['northing_start'])
    metadata['easting_start'] = float(row['easting_start'])
    metadata['down_start'] = float(row['down_start'])
    metadata['heading_start'] = float(row['heading_start'])
    metadata['timestamp_center'] = int(row['timestamp_center'])
    metadata['northing_center'] = float(row['northing_center'])
    metadata['easting_center'] = float(row['easting_center'])
    metadata['down_center'] = float(row['down_center'])
    metadata['heading_center'] = float(row['heading_center'])
    
    return metadata


def get_pcl_metadata(metadata_file, seg_idx=None):
    if seg_idx is None:
        # Return list of all metadata
        metadata = []
    else:
        # Return metadata of single submap
        metadata = None
        
    with open(metadata_file) as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            if seg_idx is None:
                metadata.append(read_metadata_csv_row(row))
            elif int(row['seg_idx']) == seg_idx:
                metadata = read_metadata_csv_row(row)
                break
    return metadata

# %%
sys.path.insert(0, sdk_dir + '/python')
import image as sdk_image
from camera_model import CameraModel

class ImageLoader():
    def __init__(self, camera_type, center_offset=None):
        self.trajectory_ned = None
        self.subset_split = None
        self.camera_type = camera_type
        self.center_offset = center_offset
        
        if camera_type == 'center':
            self.img_dir = data_dir + '/stereo/centre'
            self.timestamps_file = data_dir + '/stereo.timestamps'
            self.tgt_dir = data_dir + '/img_center'
            if center_offset is not None:
                self.tgt_dir += '_{}'.format(int(center_offset))
        elif camera_type in ['left', 'right']:
            self.img_dir = data_dir + '/mono_{}'.format(camera_type)
            self.timestamps_file = data_dir + '/mono_{}.timestamps'.format(camera_type)
            self.tgt_dir = data_dir + '/img_{}'.format(camera_type)
        else:
            raise ValueError('Wrong camera type: ', camera_type)
        
        if not os.path.isdir(self.tgt_dir):
            os.mkdir(self.tgt_dir)
            
        self.camera_model = CameraModel(sdk_dir + '/models', self.img_dir)
        
    
    def load_ned_trajectory(self, subset_split=None):
        # Get timestamps from camera data
        self.timestamps_file = np.genfromtxt(self.timestamps_file)
        self.timestamps_file = self.timestamps_file[:,0].flatten()
        start_time = self.timestamps_file[0]
        end_time = self.timestamps_file[-1]

        # Check if NED trajectory has already been computed
        trajectory_file = gps_dir + '/ned_trajectory_{}_{}.npy'.format(self.camera_type, 
                                                                       run_id)
        print('Search for precomputed NED trajectory ' + trajectory_file + '...')

        try:
            self.trajectory_ned = np.load(trajectory_file)
            print('Done!')
        except:
            print('Not found! Create camera trajectory...')
            # Get trajectory corresponding to camera data
            camera_timestamp_idx = 0
            self.trajectory_ned = np.empty((7,0))
            with open(ins_data_file, 'r') as ins_file:
                reader = csv.DictReader(ins_file)
                for row in reader:
                    if int(row['timestamp']) > end_time:
                        break
                    if int(row['timestamp']) < start_time:
                        continue

                    # Get closest corresponding camera timestamp
                    ins_timestamp = int(row['timestamp'])
                    camera_timestamp_idx = self.get_closest_camera_timestamp(
                                                ins_timestamp, camera_timestamp_idx)
                    img_timestamp = self.timestamps_file[camera_timestamp_idx]

                    camera_state = np.array([float(row['northing']),
                                             float(row['easting']),
                                             float(row['down']),
                                             float(row['roll']),
                                             float(row['pitch']),
                                             float(row['yaw']),
                                             img_timestamp]).reshape(7,1)
                    self.trajectory_ned = np.append(self.trajectory_ned, camera_state, axis=1)
 
            print('Done! Trajectory with {} samples'.format(
                                                  self.trajectory_ned.shape[1]))

            # Save trajectory
            print('Save NED trajectory to ' + trajectory_file + '...')
            np.save(trajectory_file, self.trajectory_ned)
            print('Done!')
            
        # If specified, use only a subset of the data
        if subset_split is not None:
            max_idx = int(self.trajectory_ned.shape[1] * subset_split)
            print('WARNING: We use only the first {}% of the trajectory ({} measurements)'.
                                                format(int(subset_split*100), max_idx))
            self.trajectory_ned = self.trajectory_ned[:,:max_idx]
            self.subset_split = subset_split
            
    def load_images(self, submap_length):
        # Load pointcloud metadata
        pcl_dir = data_dir + '/submaps_{}m'.format(int(submap_length))
        pcl_metadata_filename = (pcl_dir + '/metadata.csv')
        pcl_metadata = get_pcl_metadata(pcl_metadata_filename)

        # Sort list by timestamp
        pcl_metadata.sort(key=lambda pcl: pcl['timestamp_start'])

        # Create image metadata csv file
        metadata_fieldnames = ['seg_idx',
                               'camera',
                               'offset', 
                               'timestamp',
                               'northing',
                               'easting',
                               'down',
                               'heading', 
                               'dist_to_ref']
        metadata_csv = (self.tgt_dir + '/metadata.csv')

        with open(metadata_csv, 'w') as outcsv:
            writer = csv.DictWriter(outcsv, metadata_fieldnames)
            writer.writeheader()
        
        # Walk along camera trajectory and save all images belonging to a submap
        if self.camera_type == 'center':
            ref = 'start'
            offset = self.center_offset
        else:
            ref = 'center'
            offset = 0
            
        i_pcl = 0
        i_min = 0
        dist_min = 1.0e9
        ref_pos = np.array([pcl_metadata[i_pcl]['northing_'+ref],
                            pcl_metadata[i_pcl]['easting_'+ref]])
                
        for i in range(self.trajectory_ned.shape[1]):
            pos = self.trajectory_ned[:2,i]
            dist_to_ref = np.linalg.norm(pos - ref_pos)

            if dist_to_ref < dist_min:
                i_min = i
                dist_min = dist_to_ref

            if dist_to_ref > dist_min + 0.5:

                # Go back to offset
                if offset > 0:
                    dist_to_offset = offset
                    prev_pos = self.trajectory_ned[:3,i_min]
                    for i_min in range(i_min-1,-1,-1):
                        curr_pos = self.trajectory_ned[[0,1,2],i_min]
                        dist_to_offset -= np.linalg.norm(prev_pos - curr_pos)
                        prev_pos = curr_pos
                        if dist_to_offset < 0:
                            break

                print('Save image {} with dist {}'.format(i_min, dist_min))
                # Save image of step with minimum dist to reference as png
                timestamp = self.trajectory_ned[6,i_min]
                seg_idx = pcl_metadata[i_pcl]['seg_idx']

                _, pil_image = self.load_image(timestamp, size=(320,200))
                pil_image.save(self.tgt_dir + '/img_{}_{}.png'.format(submap_length, 
                                                                         seg_idx), 'PNG')

                # Save image metadata
                with open(metadata_csv, 'a') as outcsv:
                    writer = csv.DictWriter(outcsv,fieldnames=metadata_fieldnames)
                    writer.writerow({'seg_idx' : seg_idx,
                                     'camera' : self.camera_type,
                                     'offset' : self.center_offset, 
                                     'timestamp' : int(timestamp),
                                     'northing' : self.trajectory_ned[0,i_min],
                                     'easting' : self.trajectory_ned[1,i_min],
                                     'down' : self.trajectory_ned[2,i_min],
                                     'heading' : self.trajectory_ned[5,i_min], 
                                     'dist_to_ref' : dist_min})


                # Set new reference position
                i_pcl += 1
                if i_pcl == len(pcl_metadata):
                    print('Last submap reached!')
                    break
                ref_pos = np.array([pcl_metadata[i_pcl]['northing_'+ref],
                                    pcl_metadata[i_pcl]['easting_'+ref]])
                dist_min = 1.0e9
            
        
    
    def get_closest_camera_timestamp(self, ins_timestamp, start_idx):
        min_diff = 1e9
        i_min = start_idx
        for i in range(start_idx, self.timestamps_file.shape[0]):
            diff = math.fabs(ins_timestamp - self.timestamps_file[i])

            if diff < min_diff:
                min_diff = diff
                i_min = i
            else:
                break

        return i_min
    
    def load_image(self, timestamp, size=None):
        image_file = os.path.join(self.img_dir, '{}.png'.format(int(timestamp)))
        image = sdk_image.load_image(image_file, model=self.camera_model)

        pil_image = Image.fromarray(image.astype('uint8'))
        if size is not None:
            pil_image = pil_image.resize(size)

        return image, pil_image

# %%
camera_type = 'right'
offset = 0
submap_length = 20

img_loader = ImageLoader(camera_type, center_offset=offset)
img_loader.load_ned_trajectory(subset_split=0.2)
img_loader.load_images(submap_length)
# Out:
# Search for precomputed NED trajectory data/oxford/data/reference/gps/ned_trajectory_right_reference.npy...
# Done!
# WARNING: We use only the first 20% of the trajectory (18810 measurements)
# Save image 1005 with dist 0.0
# Save image 1034 with dist 0.0
# Save image 1053 with dist 0.0
# Save image 1065 with dist 0.0
# Save image 1079 with dist 0.0
# Save image 1092 with dist 0.0
# Save image 1106 with dist 0.0
# Save image 1118 with dist 0.0
# Save image 1131 with dist 0.0
# Save image 1143 with dist 0.0
# Save image 1155 with dist 0.0
# Save image 1167 with dist 0.0
# Save image 1179 with dist 0.0
# Save image 1191 with dist 0.0
# Save image 1203 with dist 0.0
# Save image 1215 with dist 0.0
# Save image 1228 with dist 0.0
# Save image 1241 with dist 0.0
# Save image 1254 with dist 0.0
# Save image 1267 with dist 0.0
# Save image 1281 with dist 0.0
# Save image 1295 with dist 0.0
# Save image 1305 with dist 0.0
# Save image 1320 with dist 0.0
# Save image 1336 with dist 0.0
# Save image 1353 with dist 0.0
# Save image 1367 with dist 0.0
# Save image 1386 with dist 0.0
# Save image 1405 with dist 0.0
# Save image 1426 with dist 0.0
# Save image 1451 with dist 0.0
# Save image 1478 with dist 0.0
# Save image 1511 with dist 0.0
# Save image 1546 with dist 0.0
# Save image 1581 with dist 0.0
# Save image 1637 with dist 0.0
# Save image 1685 with dist 0.0
# Save image 1734 with dist 0.0
# Save image 1789 with dist 0.0
# Save image 2513 with dist 0.46599769665251356
# Save image 2534 with dist 0.5850843096225358
# Save image 2550 with dist 0.7050400047213662
# Save image 2568 with dist 0.2359433452589797
# Save image 2581 with dist 0.2792802825243818
# Save image 2596 with dist 0.0
# Save image 2614 with dist 0.0
# Save image 2637 with dist 0.0
# Save image 2663 with dist 0.0
# Save image 2685 with dist 0.0
# Save image 2713 with dist 0.0
# Save image 2750 with dist 0.0
# Save image 2798 with dist 0.0
# Save image 2861 with dist 0.0
# Save image 3197 with dist 0.0
# Save image 4412 with dist 0.46433938629886284
# Save image 4435 with dist 0.19492117723359964
# Save image 4455 with dist 0.0
# Save image 4471 with dist 0.0
# Save image 4488 with dist 0.0
# Save image 4502 with dist 0.0
# Save image 4512 with dist 0.0
# Save image 4524 with dist 0.0
# Save image 4534 with dist 0.0
# Save image 4544 with dist 0.0
# Save image 4555 with dist 0.0
# Save image 4562 with dist 0.0
# Save image 4570 with dist 0.0
# Save image 4578 with dist 0.0
# Save image 4586 with dist 0.0
# Save image 4593 with dist 0.0
# Save image 4600 with dist 0.0
# Save image 4607 with dist 0.0
# Save image 4613 with dist 0.0
# Save image 4621 with dist 0.0
# Save image 4628 with dist 0.0
# Save image 4636 with dist 0.0
# Save image 4643 with dist 0.0
# Save image 4651 with dist 0.0
# Save image 4659 with dist 0.0
# Save image 4666 with dist 0.0
# Save image 4674 with dist 0.0
# Save image 4683 with dist 0.0
# Save image 4690 with dist 0.0
# Save image 4698 with dist 0.0
# Save image 4707 with dist 0.0
# Save image 4715 with dist 0.0
# Save image 4724 with dist 0.0
# Save image 4733 with dist 0.0
# Save image 4742 with dist 0.0
# Save image 4752 with dist 0.0
# Save image 4762 with dist 0.0
# Save image 4772 with dist 0.0
# Save image 4783 with dist 0.0
# Save image 4795 with dist 0.0
# Save image 4808 with dist 0.0
# Save image 4821 with dist 0.0
# Save image 4837 with dist 0.0
# Save image 4853 with dist 0.0
# Save image 4869 with dist 0.0
# Save image 4887 with dist 0.0
# Save image 4904 with dist 0.0
# Save image 4921 with dist 0.0
# Save image 4935 with dist 0.0
# Save image 4949 with dist 0.0
# Save image 4961 with dist 0.0
# Save image 4972 with dist 0.0
# Save image 4983 with dist 0.0
# Save image 4993 with dist 0.0
# Save image 5003 with dist 0.0
# Save image 5012 with dist 0.0
# Save image 5022 with dist 0.0
# Save image 5031 with dist 0.0
# Save image 5040 with dist 0.0
# Save image 5049 with dist 0.0
# Save image 5058 with dist 0.0
# Save image 5067 with dist 0.0
# Save image 5075 with dist 0.0
# Save image 5083 with dist 0.0
# Save image 5091 with dist 0.0
# Save image 5100 with dist 0.0
# Save image 5108 with dist 0.0
# Save image 5116 with dist 0.0
# Save image 5124 with dist 0.0
# Save image 5132 with dist 0.0
# Save image 5140 with dist 0.0
# Save image 5148 with dist 0.0
# Save image 5156 with dist 0.0
# Save image 5164 with dist 0.0
# Save image 5171 with dist 0.0
# Save image 5179 with dist 0.0
# Save image 5186 with dist 0.0
# Save image 5194 with dist 0.0
# Save image 5202 with dist 0.0
# Save image 5210 with dist 0.0
# Save image 5218 with dist 0.0
# Save image 5226 with dist 0.0
# Save image 5235 with dist 0.0
# Save image 5243 with dist 0.0
# Save image 5251 with dist 0.0
# Save image 5260 with dist 0.0
# Save image 5268 with dist 0.0
# Save image 5276 with dist 0.0
# Save image 5284 with dist 0.0
# Save image 5292 with dist 0.0
# Save image 5300 with dist 0.0
# Save image 5308 with dist 0.0
# Save image 5316 with dist 0.0
# Save image 5323 with dist 0.0
# Save image 5331 with dist 0.0
# Save image 5338 with dist 0.0
# Save image 5346 with dist 0.0
# Save image 5353 with dist 0.0
# Save image 5361 with dist 0.0
# Save image 5369 with dist 0.0
# Save image 5376 with dist 0.0
# Save image 5384 with dist 0.0
# Save image 5392 with dist 0.0
# Save image 5399 with dist 0.0
# Save image 5407 with dist 0.0
# Save image 5415 with dist 0.0
# Save image 5423 with dist 0.0
# Save image 5431 with dist 0.0
# Save image 5438 with dist 0.0
# Save image 5446 with dist 0.0
# Save image 5454 with dist 0.0
# Save image 5462 with dist 0.0
# Save image 5470 with dist 0.0
# Save image 5478 with dist 0.0
# Save image 5485 with dist 0.0
# Save image 5492 with dist 0.0
# Save image 5499 with dist 0.0
# Save image 5506 with dist 0.0
# Save image 5513 with dist 0.0
# Save image 5520 with dist 0.0
# Save image 5526 with dist 0.0
# Save image 5533 with dist 0.0
# Save image 5540 with dist 0.0
# Save image 5547 with dist 0.0
# Save image 5554 with dist 0.0
# Save image 5561 with dist 0.0
# Save image 5567 with dist 0.0
# Save image 5574 with dist 0.0
# Save image 5581 with dist 0.0
# Save image 5588 with dist 0.0
# Save image 5595 with dist 0.0
# Save image 5602 with dist 0.0
# Save image 5609 with dist 0.0
# Save image 5616 with dist 0.0
# Save image 5623 with dist 0.0
# Save image 5630 with dist 0.0
# Save image 5637 with dist 0.0
# Save image 5644 with dist 0.0
# Save image 5651 with dist 0.0
# Save image 5658 with dist 0.0
# Save image 5665 with dist 0.0
# Save image 5672 with dist 0.0
# Save image 5679 with dist 0.0
# Save image 5686 with dist 0.0
# Save image 5692 with dist 0.0
# Save image 5699 with dist 0.0
# Save image 5706 with dist 0.0
# Save image 5712 with dist 0.0
# Save image 5719 with dist 0.0
# Save image 5726 with dist 0.0
# Save image 5732 with dist 0.0
# Save image 5739 with dist 0.0
# Save image 5746 with dist 0.0
# Save image 5752 with dist 0.0
# Save image 5759 with dist 0.0
# Save image 5766 with dist 0.0
# Save image 5773 with dist 0.0
# Save image 5780 with dist 0.0
# Save image 5787 with dist 0.0
# Save image 5794 with dist 0.0
# Save image 5801 with dist 0.0
# Save image 5808 with dist 0.0
# Save image 5815 with dist 0.0
# Save image 5822 with dist 0.0
# Save image 5829 with dist 0.0
# Save image 5837 with dist 0.0
# Save image 5844 with dist 0.0
# Save image 5852 with dist 0.0
# Save image 5859 with dist 0.0
# Save image 5866 with dist 0.0
# Save image 5874 with dist 0.0
# Save image 5881 with dist 0.0
# Save image 5889 with dist 0.0
# Save image 5896 with dist 0.0
# Save image 5903 with dist 0.0
# Save image 5911 with dist 0.0
# Save image 5918 with dist 0.0
# Save image 5926 with dist 0.0
# Save image 5933 with dist 0.0
# Save image 5941 with dist 0.0
# Save image 5948 with dist 0.0
# Save image 5956 with dist 0.0
# Save image 5963 with dist 0.0
# Save image 5970 with dist 0.0
# Save image 5979 with dist 0.0
# Save image 5987 with dist 0.0
# Save image 5995 with dist 0.0
# Save image 6003 with dist 0.0
# Save image 6011 with dist 0.0
# Save image 6018 with dist 0.0
# Save image 6026 with dist 0.0
# Save image 6033 with dist 0.0
# Save image 6040 with dist 0.0
# Save image 6047 with dist 0.0
# Save image 6054 with dist 0.0
# Save image 6061 with dist 0.0
# Save image 6068 with dist 0.0
# Save image 6075 with dist 0.0
# Save image 6081 with dist 0.0
# Save image 6088 with dist 0.0
# Save image 6094 with dist 0.0
# Save image 6100 with dist 0.0
# Save image 6107 with dist 0.0
# Save image 6113 with dist 0.0
# Save image 6120 with dist 0.0
# Save image 6126 with dist 0.0
# Save image 6133 with dist 0.0
# Save image 6139 with dist 0.0
# Save image 6146 with dist 0.0
# Save image 6153 with dist 0.0
# Save image 6159 with dist 0.0
# Save image 6166 with dist 0.0
# Save image 6173 with dist 0.0
# Save image 6178 with dist 0.0
# Save image 6184 with dist 0.0
# Save image 6190 with dist 0.0
# Save image 6195 with dist 0.0
# Save image 6201 with dist 0.0
# Save image 6207 with dist 0.0
# Save image 6213 with dist 0.0
# Save image 6218 with dist 0.0
# Save image 6224 with dist 0.0
# Save image 6230 with dist 0.0
# Save image 6236 with dist 0.0
# Save image 6242 with dist 0.0
# Save image 6248 with dist 0.0
# Save image 6254 with dist 0.0
# Save image 6260 with dist 0.0
# Save image 6265 with dist 0.0
# Save image 6270 with dist 0.0
# Save image 6276 with dist 0.0
# Save image 6282 with dist 0.0
# Save image 6288 with dist 0.0
# Save image 6294 with dist 0.0
# Save image 6300 with dist 0.0
# Save image 6305 with dist 0.0
# Save image 6311 with dist 0.0
# Save image 6316 with dist 0.0
# Save image 6322 with dist 0.0
# Save image 6328 with dist 0.0
# Save image 6334 with dist 0.0
# Save image 6340 with dist 0.0
# Save image 6346 with dist 0.0
# Save image 6352 with dist 0.0
# Save image 6358 with dist 0.0
# Save image 6364 with dist 0.0
# Save image 6370 with dist 0.0
# Save image 6376 with dist 0.0
# Save image 6382 with dist 0.0
# Save image 6388 with dist 0.0
# Save image 6394 with dist 0.0
# Save image 6400 with dist 0.0
# Save image 6406 with dist 0.0
# Save image 6411 with dist 0.0
# Save image 6417 with dist 0.0
# Save image 6423 with dist 0.0
# Save image 6430 with dist 0.0
# Save image 6436 with dist 0.0
# Save image 6442 with dist 0.0
# Save image 6448 with dist 0.0
# Save image 6454 with dist 0.0
# Save image 6461 with dist 0.0
# Save image 6466 with dist 0.0
# Save image 6472 with dist 0.0
# Save image 6479 with dist 0.0
# Save image 6485 with dist 0.0
# Save image 6491 with dist 0.0
# Save image 6497 with dist 0.0
# Save image 6503 with dist 0.0
# Save image 6510 with dist 0.0
# Save image 6515 with dist 0.0
# Save image 6522 with dist 0.0
# Save image 6528 with dist 0.0
# Save image 6535 with dist 0.0
# Save image 6541 with dist 0.0
# Save image 6547 with dist 0.0
# Save image 6553 with dist 0.0
# Save image 6560 with dist 0.0
# Save image 6566 with dist 0.0
# Save image 6573 with dist 0.0
# Save image 6579 with dist 0.0
# Save image 6585 with dist 0.0
# Save image 6592 with dist 0.0
# Save image 6598 with dist 0.0
# Save image 6604 with dist 0.0
# Save image 6611 with dist 0.0
# Save image 6617 with dist 0.0
# Save image 6624 with dist 0.0
# Save image 6632 with dist 0.0
# Save image 6639 with dist 0.0
# Save image 6647 with dist 0.0
# Save image 6654 with dist 0.0
# Save image 6661 with dist 0.0
# Save image 6670 with dist 0.0
# Save image 6678 with dist 0.0
# Save image 6687 with dist 0.0
# Save image 6696 with dist 0.0
# Save image 6704 with dist 0.0
# Save image 6713 with dist 0.0
# Save image 6722 with dist 0.0
# Save image 6731 with dist 0.0
# Save image 6743 with dist 0.0
# Save image 6754 with dist 0.0
# Save image 6765 with dist 0.0
# Save image 6777 with dist 0.0
# Save image 6789 with dist 0.0
# Save image 6803 with dist 0.0
# Save image 6817 with dist 0.0
# Save image 6833 with dist 0.0
# Save image 6850 with dist 0.0
# Save image 6868 with dist 0.0
# Save image 6894 with dist 0.0
# Save image 6937 with dist 0.0
# Save image 7076 with dist 0.0
# Save image 7113 with dist 0.0
# Save image 7133 with dist 0.0
# Save image 7148 with dist 0.0
# Save image 7161 with dist 0.0
# Save image 7171 with dist 0.0
# Save image 7182 with dist 0.0
# Save image 7192 with dist 0.0
# Save image 7201 with dist 0.0
# Save image 7208 with dist 0.0
# Save image 7215 with dist 0.0
# Save image 7222 with dist 0.0
# Save image 7230 with dist 0.0
# Save image 7237 with dist 0.0
# Save image 7243 with dist 0.0
# Save image 7250 with dist 0.0
# Save image 7256 with dist 0.0
# Save image 7262 with dist 0.0
# Save image 7267 with dist 0.0
# Save image 7273 with dist 0.0
# Save image 7279 with dist 0.0
# Save image 7284 with dist 0.0
# Save image 7290 with dist 0.0
# Save image 7295 with dist 0.0
# Save image 7301 with dist 0.0
# Save image 7306 with dist 0.0
# Save image 7311 with dist 0.0
# Save image 7316 with dist 0.0
# Save image 7322 with dist 0.0
# Save image 7327 with dist 0.0
# Save image 7333 with dist 0.0
# Save image 7339 with dist 0.0
# Save image 7345 with dist 0.0
# Save image 7351 with dist 0.0
# Save image 7356 with dist 0.0
# Save image 7361 with dist 0.0
# Save image 7366 with dist 0.0
# Save image 7371 with dist 0.0
# Save image 7376 with dist 0.0
# Save image 7381 with dist 0.0
# Save image 7387 with dist 0.0
# Save image 7392 with dist 0.0
# Save image 7397 with dist 0.0
# Save image 7402 with dist 0.0
# Save image 7407 with dist 0.0
# Save image 7413 with dist 0.0
# Save image 7419 with dist 0.0
# Save image 7425 with dist 0.0
# Save image 7431 with dist 0.0
# Save image 7436 with dist 0.0
# Save image 7442 with dist 0.0
# Save image 7448 with dist 0.0
# Save image 7454 with dist 0.0
# Save image 7460 with dist 0.0
# Save image 7465 with dist 0.0
# Save image 7470 with dist 0.0
# Save image 7475 with dist 0.0
# Save image 7479 with dist 0.0
# Save image 7484 with dist 0.0
# Save image 7489 with dist 0.0
# Save image 7494 with dist 0.0
# Save image 7499 with dist 0.0
# Save image 7503 with dist 0.0
# Save image 7508 with dist 0.0
# Save image 7513 with dist 0.0
# Save image 7518 with dist 0.0
# Save image 7523 with dist 0.0
# Save image 7528 with dist 0.0
# Save image 7533 with dist 0.0
# Save image 7538 with dist 0.0
# Save image 7543 with dist 0.0
# Save image 7548 with dist 0.0
# Save image 7554 with dist 0.0
# Save image 7558 with dist 0.0
# Save image 7564 with dist 0.0
# Save image 7569 with dist 0.0
# Save image 7574 with dist 0.0
# Save image 7579 with dist 0.0
# Save image 7584 with dist 0.0
# Save image 7589 with dist 0.0
# Save image 7594 with dist 0.0
# Save image 7599 with dist 0.0
# Save image 7604 with dist 0.0
# Save image 7609 with dist 0.0
# Save image 7614 with dist 0.0
# Save image 7620 with dist 0.0
# Save image 7625 with dist 0.0
# Save image 7630 with dist 0.0
# Save image 7635 with dist 0.0
# Save image 7639 with dist 0.0
# Save image 7644 with dist 0.0
# Save image 7649 with dist 0.0
# Save image 7654 with dist 0.0
# Save image 7660 with dist 0.0
# Save image 7665 with dist 0.0
# Save image 7670 with dist 0.0
# Save image 7675 with dist 0.0
# Save image 7680 with dist 0.0
# Save image 7684 with dist 0.0
# Save image 7689 with dist 0.0
# Save image 7694 with dist 0.0
# Save image 7699 with dist 0.0
# Save image 7704 with dist 0.0
# Save image 7709 with dist 0.0
# Save image 7714 with dist 0.0
# Save image 7719 with dist 0.0
# Save image 7724 with dist 0.0
# Save image 7729 with dist 0.0
# Save image 7733 with dist 0.0
# Save image 7738 with dist 0.0
# Save image 7743 with dist 0.0
# Save image 7748 with dist 0.0
# Save image 7753 with dist 0.0
# Save image 7758 with dist 0.0
# Save image 7763 with dist 0.0
# Save image 7768 with dist 0.0
# Save image 7773 with dist 0.0
# Save image 7778 with dist 0.0
# Save image 7783 with dist 0.0
# Save image 7788 with dist 0.0
# Save image 7793 with dist 0.0
# Save image 7798 with dist 0.0
# Save image 7802 with dist 0.0
# Save image 7807 with dist 0.0
# Save image 7812 with dist 0.0
# Save image 7817 with dist 0.0
# Save image 7822 with dist 0.0
# Save image 7827 with dist 0.0
# Save image 7832 with dist 0.0
# Save image 7837 with dist 0.0
# Save image 7842 with dist 0.0
# Save image 7847 with dist 0.0
# Save image 7852 with dist 0.0
# Save image 7857 with dist 0.0
# Save image 7862 with dist 0.0
# Save image 7867 with dist 0.0
# Save image 7872 with dist 0.0
# Save image 7877 with dist 0.0
# Save image 7882 with dist 0.0
# Save image 7887 with dist 0.0
# Save image 7892 with dist 0.0
# Save image 7897 with dist 0.0
# Save image 7902 with dist 0.0
# Save image 7907 with dist 0.0
# Save image 7912 with dist 0.0
# Save image 7917 with dist 0.0
# Save image 7922 with dist 0.0
# Save image 7927 with dist 0.0
# Save image 7932 with dist 0.0
# Save image 7937 with dist 0.0
# Save image 7942 with dist 0.0
# Save image 7946 with dist 0.0
# Save image 7951 with dist 0.0
# Save image 7956 with dist 0.0
# Save image 7961 with dist 0.0
# Save image 7966 with dist 0.0
# Save image 7971 with dist 0.0
# Save image 7976 with dist 0.0
# Save image 7981 with dist 0.0
# Save image 7986 with dist 0.0
# Save image 7991 with dist 0.0
# Save image 7996 with dist 0.0
# Save image 8001 with dist 0.0
# Save image 8006 with dist 0.0
# Save image 8011 with dist 0.0
# Save image 8016 with dist 0.0
# Save image 8021 with dist 0.0
# Save image 8026 with dist 0.0
# Save image 8031 with dist 0.0
# Save image 8036 with dist 0.0
# Save image 8041 with dist 0.0
# Save image 8046 with dist 0.0
# Save image 8051 with dist 0.0
# Save image 8056 with dist 0.0
# Save image 8061 with dist 0.0
# Save image 8066 with dist 0.0
# Save image 8071 with dist 0.0
# Save image 8077 with dist 0.0
# Save image 8082 with dist 0.0
# Save image 8087 with dist 0.0
# Save image 8092 with dist 0.0
# Save image 8097 with dist 0.0
# Save image 8102 with dist 0.0
# Save image 8107 with dist 0.0
# Save image 8112 with dist 0.0
# Save image 8117 with dist 0.0
# Save image 8123 with dist 0.0
# Save image 8128 with dist 0.0
# Save image 8133 with dist 0.0
# Save image 8138 with dist 0.0
# Save image 8143 with dist 0.0
# Save image 8148 with dist 0.0
# Save image 8153 with dist 0.0
# Save image 8158 with dist 0.0
# Save image 8163 with dist 0.0
# Save image 8168 with dist 0.0
# Save image 8173 with dist 0.0
# Save image 8178 with dist 0.0
# Save image 8183 with dist 0.0
# Save image 8188 with dist 0.0
# Save image 8193 with dist 0.0
# Save image 8198 with dist 0.0
# Save image 8202 with dist 0.0
# Save image 8207 with dist 0.0
# Save image 8212 with dist 0.0
# Save image 8217 with dist 0.0
# Save image 8222 with dist 0.0
# Save image 8227 with dist 0.0
# Save image 8232 with dist 0.0
# Save image 8237 with dist 0.0
# Save image 8242 with dist 0.0
# Save image 8247 with dist 0.0
# Save image 8252 with dist 0.0
# Save image 8257 with dist 0.0
# Save image 8262 with dist 0.0
# Save image 8267 with dist 0.0
# Save image 8272 with dist 0.0
# Save image 8277 with dist 0.0
# Save image 8282 with dist 0.0
# Save image 8287 with dist 0.0
# Save image 8292 with dist 0.0
# Save image 8297 with dist 0.0
# Save image 8302 with dist 0.0
# Save image 8307 with dist 0.0
# Save image 8312 with dist 0.0
# Save image 8317 with dist 0.0
# Save image 8322 with dist 0.0
# Save image 8327 with dist 0.0
# Save image 8332 with dist 0.0
# Save image 8337 with dist 0.0
# Save image 8343 with dist 0.0
# Save image 8348 with dist 0.0
# Save image 8353 with dist 0.0
# Save image 8358 with dist 0.0
# Save image 8363 with dist 0.0
# Save image 8368 with dist 0.0
# Save image 8373 with dist 0.0
# Save image 8378 with dist 0.0
# Save image 8383 with dist 0.0
# Save image 8388 with dist 0.0
# Save image 8393 with dist 0.0
# Save image 8398 with dist 0.0
# Save image 8404 with dist 0.0
# Save image 8409 with dist 0.0
# Save image 8414 with dist 0.0
# Save image 8419 with dist 0.0
# Save image 8424 with dist 0.0
# Save image 8429 with dist 0.0
# Save image 8434 with dist 0.0
# Save image 8440 with dist 0.0
# Save image 8445 with dist 0.0
# Save image 8450 with dist 0.0
# Save image 8455 with dist 0.0
# Save image 8460 with dist 0.0
# Save image 8465 with dist 0.0
# Save image 8470 with dist 0.0
# Save image 8475 with dist 0.0
# Save image 8480 with dist 0.0
# Save image 8485 with dist 0.0
# Save image 8490 with dist 0.0
# Save image 8495 with dist 0.0
# Save image 8501 with dist 0.0
# Save image 8506 with dist 0.0
# Save image 8510 with dist 0.0
# Save image 8516 with dist 0.0
# Save image 8521 with dist 0.0
# Save image 8526 with dist 0.0
# Save image 8531 with dist 0.0
# Save image 8536 with dist 0.0
# Save image 8541 with dist 0.0
# Save image 8546 with dist 0.0
# Save image 8551 with dist 0.0
# Save image 8556 with dist 0.0
# Save image 8561 with dist 0.0
# Save image 8566 with dist 0.0
# Save image 8572 with dist 0.0
# Save image 8577 with dist 0.0
# Save image 8582 with dist 0.0
# Save image 8587 with dist 0.0
# Save image 8592 with dist 0.0
# Save image 8597 with dist 0.0
# Save image 8602 with dist 0.0
# Save image 8607 with dist 0.0
# Save image 8613 with dist 0.0
# Save image 8618 with dist 0.0
# Save image 8623 with dist 0.0
# Save image 8629 with dist 0.0
# Save image 8635 with dist 0.0
# Save image 8641 with dist 0.0
# Save image 8647 with dist 0.0
# Save image 8653 with dist 0.0
# Save image 8659 with dist 0.0
# Save image 8665 with dist 0.0
# Save image 8671 with dist 0.0
# Save image 8677 with dist 0.0
# Save image 8683 with dist 0.0
# Save image 8689 with dist 0.0
# Save image 8696 with dist 0.0
# Save image 8702 with dist 0.0
# Save image 8708 with dist 0.0
# Save image 8714 with dist 0.0
# Save image 8721 with dist 0.0
# Save image 8727 with dist 0.0
# Save image 8733 with dist 0.0
# Save image 8739 with dist 0.0
# Save image 8746 with dist 0.0
# Save image 8752 with dist 0.0
# Save image 8758 with dist 0.0
# Save image 8764 with dist 0.0
# Save image 8771 with dist 0.0
# Save image 8777 with dist 0.0
# Save image 8783 with dist 0.0
# Save image 8789 with dist 0.0
# Save image 8796 with dist 0.0
# Save image 8802 with dist 0.0
# Save image 8808 with dist 0.0
# Save image 8815 with dist 0.0
# Save image 8821 with dist 0.0
# Save image 8828 with dist 0.0
# Save image 8834 with dist 0.0
# Save image 8841 with dist 0.0
# Save image 8848 with dist 0.0
# Save image 8854 with dist 0.0
# Save image 8861 with dist 0.0
# Save image 8868 with dist 0.0
# Save image 8875 with dist 0.0
# Save image 8882 with dist 0.0
# Save image 8890 with dist 0.0
# Save image 8898 with dist 0.0
# Save image 8906 with dist 0.0
# Save image 8915 with dist 0.0
# Save image 8923 with dist 0.0
# Save image 8931 with dist 0.0
# Save image 8940 with dist 0.0
# Save image 8949 with dist 0.0
# Save image 8957 with dist 0.0
# Save image 8965 with dist 0.0
# Save image 8976 with dist 0.0
# Save image 8986 with dist 0.0
# Save image 8996 with dist 0.0
# Save image 9007 with dist 0.0
# Save image 9018 with dist 0.0
# Save image 9029 with dist 0.0
# Save image 9042 with dist 0.0
# Save image 9055 with dist 0.0
# Save image 9070 with dist 0.0
# Save image 9085 with dist 0.0
# Save image 9105 with dist 0.0
# Save image 9128 with dist 0.0
# Save image 9160 with dist 0.0
# Save image 9210 with dist 0.0
# Save image 9300 with dist 0.0
# Save image 9664 with dist 0.0
# Save image 10360 with dist 0.008534506504500387
# Save image 12611 with dist 0.5567110957174854
# Save image 12645 with dist 0.8841780914339211
# Save image 12661 with dist 0.5294640891946736
# Save image 12676 with dist 0.11583061007724733
# Save image 12696 with dist 0.0
# Save image 12712 with dist 0.0
# Save image 12729 with dist 0.0
# Save image 12745 with dist 0.0
# Save image 12759 with dist 0.0
# Save image 12770 with dist 0.0
# Save image 12782 with dist 0.0
# Save image 12797 with dist 0.0
# Save image 12811 with dist 0.0
# Save image 12823 with dist 0.0
# Save image 12836 with dist 0.0
# Save image 12849 with dist 0.0
# Save image 12861 with dist 0.0
# Save image 12875 with dist 0.0
# Save image 12889 with dist 0.0
# Save image 12903 with dist 0.0
# Save image 12916 with dist 0.0
# Save image 12930 with dist 0.0
# Save image 12945 with dist 0.0
# Save image 12960 with dist 0.0
# Save image 12976 with dist 0.0
# Save image 12991 with dist 0.0
# Save image 13006 with dist 0.0
# Save image 13020 with dist 0.0
# Save image 13034 with dist 0.0
# Save image 13046 with dist 0.0
# Save image 13058 with dist 0.0
# Save image 13070 with dist 0.0
# Save image 13082 with dist 0.0
# Save image 13093 with dist 0.0
# Save image 13105 with dist 0.0
# Save image 13117 with dist 0.0
# Save image 13128 with dist 0.0
# Save image 13140 with dist 0.0
# Save image 13151 with dist 0.0
# Save image 13163 with dist 0.0
# Save image 13175 with dist 0.0
# Save image 13186 with dist 0.0
# Save image 13198 with dist 0.0
# Save image 13209 with dist 0.0
# Save image 13221 with dist 0.0
# Save image 13232 with dist 0.0
# Save image 13243 with dist 0.0
# Save image 13254 with dist 0.0
# Save image 13265 with dist 0.0
# Save image 13275 with dist 0.0
# Save image 13285 with dist 0.0
# Save image 13295 with dist 0.0
# Save image 13304 with dist 0.0
# Save image 13313 with dist 0.0
# Save image 13322 with dist 0.0
# Save image 13330 with dist 0.0
# Save image 13339 with dist 0.0
# Save image 13348 with dist 0.0
# Save image 13356 with dist 0.0
# Save image 13364 with dist 0.0
# Save image 13372 with dist 0.0
# Save image 13380 with dist 0.0
# Save image 13388 with dist 0.0
# Save image 13396 with dist 0.0
# Save image 13403 with dist 0.0
# Save image 13411 with dist 0.0
# Save image 13419 with dist 0.0
# Save image 13426 with dist 0.0
# Save image 13434 with dist 0.0
# Save image 13442 with dist 0.0
# Save image 13449 with dist 0.0
# Save image 13456 with dist 0.0
# Save image 13464 with dist 0.0
# Save image 13471 with dist 0.0
# Save image 13479 with dist 0.0
# Save image 13485 with dist 0.0
# Save image 13493 with dist 0.0
# Save image 13501 with dist 0.0
# Save image 13508 with dist 0.0
# Save image 13515 with dist 0.0
# Save image 13521 with dist 0.0
# Save image 13528 with dist 0.0
# Save image 13535 with dist 0.0
# Save image 13542 with dist 0.0
# Save image 13549 with dist 0.0
# Save image 13555 with dist 0.0
# Save image 13562 with dist 0.0
# Save image 13568 with dist 0.0
# Save image 13574 with dist 0.0
# Save image 13581 with dist 0.0
# Save image 13587 with dist 0.0
# Save image 13594 with dist 0.0
# Save image 13600 with dist 0.0
# Save image 13606 with dist 0.0
# Save image 13613 with dist 0.0
# Save image 13619 with dist 0.0
# Save image 13625 with dist 0.0
# Save image 13632 with dist 0.0
# Save image 13638 with dist 0.0
# Save image 13645 with dist 0.0
# Save image 13650 with dist 0.0
# Save image 13656 with dist 0.0
# Save image 13662 with dist 0.0
# Save image 13668 with dist 0.0
# Save image 13673 with dist 0.0
# Save image 13679 with dist 0.0
# Save image 13685 with dist 0.0
# Save image 13691 with dist 0.0
# Save image 13697 with dist 0.0
# Save image 13703 with dist 0.0
# Save image 13708 with dist 0.0
# Save image 13714 with dist 0.0
# Save image 13720 with dist 0.0
# Save image 13726 with dist 0.0
# Save image 13732 with dist 0.0
# Save image 13738 with dist 0.0
# Save image 13743 with dist 0.0
# Save image 13749 with dist 0.0
# Save image 13755 with dist 0.0
# Save image 13761 with dist 0.0
# Save image 13767 with dist 0.0
# Save image 13773 with dist 0.0
# Save image 13778 with dist 0.0
# Save image 13784 with dist 0.0
# Save image 13790 with dist 0.0
# Save image 13796 with dist 0.0
# Save image 13802 with dist 0.0
# Save image 13808 with dist 0.0
# Save image 13814 with dist 0.0
# Save image 13820 with dist 0.0
# Save image 13826 with dist 0.0
# Save image 13832 with dist 0.0
# Save image 13838 with dist 0.0
# Save image 13844 with dist 0.0
# Save image 13849 with dist 0.0
# Save image 13855 with dist 0.0
# Save image 13861 with dist 0.0
# Save image 13867 with dist 0.0
# Save image 13873 with dist 0.0
# Save image 13879 with dist 0.0
# Save image 13885 with dist 0.0
# Save image 13891 with dist 0.0
# Save image 13896 with dist 0.0
# Save image 13902 with dist 0.0
# Save image 13908 with dist 0.0
# Save image 13914 with dist 0.0
# Save image 13920 with dist 0.0
# Save image 13926 with dist 0.0
# Save image 13932 with dist 0.0
# Save image 13938 with dist 0.0
# Save image 13944 with dist 0.0
# Save image 13950 with dist 0.0
# Save image 13956 with dist 0.0
# Save image 13962 with dist 0.0
# Save image 13968 with dist 0.0
# Save image 13974 with dist 0.0
# Save image 13980 with dist 0.0
# Save image 13987 with dist 0.0
# Save image 13994 with dist 0.0
# Save image 14000 with dist 0.0
# Save image 14007 with dist 0.0
# Save image 14014 with dist 0.0
# Save image 14021 with dist 0.0
# Save image 14027 with dist 0.0
# Save image 14034 with dist 0.0
# Save image 14041 with dist 0.0
# Save image 14047 with dist 0.0
# Save image 14053 with dist 0.0
# Save image 14059 with dist 0.0
# Save image 14065 with dist 0.0
# Save image 14071 with dist 0.0
# Save image 14077 with dist 0.0
# Save image 14082 with dist 0.0
# Save image 14088 with dist 0.0
# Save image 14094 with dist 0.0
# Save image 14099 with dist 0.0
# Save image 14105 with dist 0.0
# Save image 14111 with dist 0.0
# Save image 14116 with dist 0.0
# Save image 14122 with dist 0.0
# Save image 14128 with dist 0.0
# Save image 14134 with dist 0.0
# Save image 14140 with dist 0.0
# Save image 14145 with dist 0.0
# Save image 14151 with dist 0.0
# Save image 14157 with dist 0.0
# Save image 14162 with dist 0.0
# Save image 14168 with dist 0.0
# Save image 14174 with dist 0.0
# Save image 14179 with dist 0.0
# Save image 14185 with dist 0.0
# Save image 14191 with dist 0.0
# Save image 14196 with dist 0.0
# Save image 14202 with dist 0.0
# Save image 14208 with dist 0.0
# Save image 14213 with dist 0.0
# Save image 14218 with dist 0.0
# Save image 14224 with dist 0.0
# Save image 14230 with dist 0.0
# Save image 14236 with dist 0.0
# Save image 14242 with dist 0.0
# Save image 14248 with dist 0.0
# Save image 14254 with dist 0.0
# Save image 14260 with dist 0.0
# Save image 14265 with dist 0.0
# Save image 14271 with dist 0.0
# Save image 14277 with dist 0.0
# Save image 14284 with dist 0.0
# Save image 14290 with dist 0.0
# Save image 14296 with dist 0.0
# Save image 14302 with dist 0.0
# Save image 14308 with dist 0.0
# Save image 14312 with dist 0.0
# Save image 14318 with dist 0.0
# Save image 14324 with dist 0.0
# Save image 14330 with dist 0.0
# Save image 14336 with dist 0.0
# Save image 14342 with dist 0.0
# Save image 14348 with dist 0.0
# Save image 14354 with dist 0.0
# Save image 14360 with dist 0.0
# Save image 14365 with dist 0.0
# Save image 14371 with dist 0.0
# Save image 14376 with dist 0.0
# Save image 14382 with dist 0.0
# Save image 14388 with dist 0.0
# Save image 14394 with dist 0.0
# Save image 14400 with dist 0.0
# Save image 14406 with dist 0.0
# Save image 14411 with dist 0.0
# Save image 14417 with dist 0.0
# Save image 14423 with dist 0.0
# Save image 14429 with dist 0.0
# Save image 14435 with dist 0.0
# Save image 14441 with dist 0.0
# Save image 14447 with dist 0.0
# Save image 14453 with dist 0.0
# Save image 14457 with dist 0.0
# Save image 14462 with dist 0.0
# Save image 14467 with dist 0.0
# Save image 14472 with dist 0.0
# Save image 14477 with dist 0.0
# Save image 14482 with dist 0.0
# Save image 14487 with dist 0.0
# Save image 14492 with dist 0.0
# Save image 14497 with dist 0.0
# Save image 14502 with dist 0.0
# Save image 14507 with dist 0.0
# Save image 14512 with dist 0.0
# Save image 14517 with dist 0.0
# Save image 14522 with dist 0.0
# Save image 14527 with dist 0.0
# Save image 14532 with dist 0.0
# Save image 14537 with dist 0.0
# Save image 14542 with dist 0.0
# Save image 14547 with dist 0.0
# Save image 14552 with dist 0.0
# Save image 14557 with dist 0.0
# Save image 14562 with dist 0.0
# Save image 14567 with dist 0.0
# Save image 14573 with dist 0.0
# Save image 14578 with dist 0.0
# Save image 14583 with dist 0.0
# Save image 14588 with dist 0.0
# Save image 14593 with dist 0.0
# Save image 14598 with dist 0.0
# Save image 14603 with dist 0.0
# Save image 14609 with dist 0.0
# Save image 14615 with dist 0.0
# Save image 14621 with dist 0.0
# Save image 14627 with dist 0.0
# Save image 14633 with dist 0.0
# Save image 14639 with dist 0.0
# Save image 14645 with dist 0.0
# Save image 14651 with dist 0.0
# Save image 14658 with dist 0.0
# Save image 14663 with dist 0.0
# Save image 14669 with dist 0.0
# Save image 14675 with dist 0.0
# Save image 14681 with dist 0.0
# Save image 14687 with dist 0.0
# Save image 14694 with dist 0.0
# Save image 14700 with dist 0.0
# Save image 14706 with dist 0.0
# Save image 14712 with dist 0.0
# Save image 14718 with dist 0.0
# Save image 14725 with dist 0.0
# Save image 14731 with dist 0.0
# Save image 14737 with dist 0.0
# Save image 14743 with dist 0.0
# Save image 14750 with dist 0.0
# Save image 14756 with dist 0.0
# Save image 14762 with dist 0.0
# Save image 14768 with dist 0.0
# Save image 14775 with dist 0.0
# Save image 14781 with dist 0.0
# Save image 14787 with dist 0.0
# Save image 14793 with dist 0.0
# Save image 14800 with dist 0.0
# Save image 14806 with dist 0.0
# Save image 14812 with dist 0.0
# Save image 14819 with dist 0.0
# Save image 14825 with dist 0.0
# Save image 14831 with dist 0.0
# Save image 14838 with dist 0.0
# Save image 14844 with dist 0.0
# Save image 14850 with dist 0.0
# Save image 14857 with dist 0.0
# Save image 14863 with dist 0.0
# Save image 14869 with dist 0.0
# Save image 14876 with dist 0.0
# Save image 14882 with dist 0.0
# Save image 14888 with dist 0.0
# Save image 14895 with dist 0.0
# Save image 14901 with dist 0.0
# Save image 14908 with dist 0.0
# Save image 14916 with dist 0.0
# Save image 14923 with dist 0.0
# Save image 14931 with dist 0.0
# Save image 14938 with dist 0.0
# Save image 14945 with dist 0.0
# Save image 14953 with dist 0.0
# Save image 14961 with dist 0.0
# Save image 14968 with dist 0.0
# Save image 14976 with dist 0.0
# Save image 14984 with dist 0.0
# Save image 14992 with dist 0.0
# Save image 15000 with dist 0.0
# Save image 15008 with dist 0.0
# Save image 15015 with dist 0.0
# Save image 15023 with dist 0.0
# Save image 15031 with dist 0.0
# Save image 15040 with dist 0.0
# Save image 15048 with dist 0.0
# Save image 15058 with dist 0.0
# Save image 15066 with dist 0.0
# Save image 15077 with dist 0.0
# Save image 15087 with dist 0.0
# Save image 15099 with dist 0.0
# Save image 15110 with dist 0.0
# Save image 15121 with dist 0.0
# Save image 15136 with dist 0.0
# Save image 15154 with dist 0.0
# Save image 15175 with dist 0.0
# Save image 15213 with dist 0.0
# Save image 15327 with dist 0.0
# Save image 15375 with dist 0.0
# Save image 15401 with dist 0.0
# Save image 15419 with dist 0.0
# Save image 15435 with dist 0.0
# Save image 15449 with dist 0.0
# Save image 15461 with dist 0.0
# Save image 15473 with dist 0.0
# Save image 15484 with dist 0.0
# Save image 15494 with dist 0.0
# Save image 15504 with dist 0.0
# Save image 15513 with dist 0.0
# Save image 15522 with dist 0.0
# Save image 15531 with dist 0.0
# Save image 15540 with dist 0.0
# Save image 15548 with dist 0.0
# Save image 15557 with dist 0.0
# Save image 15564 with dist 0.0
# Save image 15572 with dist 0.0
# Save image 15580 with dist 0.0
# Save image 15588 with dist 0.0
# Save image 15596 with dist 0.0
# Save image 15604 with dist 0.0
# Save image 15611 with dist 0.0
# Save image 15619 with dist 0.0
# Save image 15627 with dist 0.0
# Save image 15634 with dist 0.0
# Save image 15641 with dist 0.0
# Save image 15649 with dist 0.0
# Save image 15656 with dist 0.0
# Save image 15663 with dist 0.0
# Save image 15671 with dist 0.0
# Save image 15679 with dist 0.0
# Save image 15687 with dist 0.0
# Save image 15695 with dist 0.0
# Save image 15703 with dist 0.0
# Save image 15711 with dist 0.0
# Save image 15719 with dist 0.0
# Save image 15727 with dist 0.0
# Save image 15735 with dist 0.0
# Save image 15744 with dist 0.0
# Save image 15752 with dist 0.0
# Save image 15760 with dist 0.0
# Save image 15769 with dist 0.0
# Save image 15778 with dist 0.0
# Save image 15786 with dist 0.0
# Save image 15794 with dist 0.0
# Save image 15803 with dist 0.0
# Save image 15812 with dist 0.0
# Save image 15820 with dist 0.0
# Save image 15829 with dist 0.0
# Save image 15839 with dist 0.0
# Save image 15848 with dist 0.0
# Save image 15857 with dist 0.0
# Save image 15867 with dist 0.0
# Save image 15877 with dist 0.0
# Save image 15888 with dist 0.0
# Save image 15899 with dist 0.0
# Save image 15910 with dist 0.0
# Save image 15921 with dist 0.0
# Save image 15932 with dist 0.0
# Save image 15943 with dist 0.0
# Save image 15954 with dist 0.0
# Save image 15965 with dist 0.0
# Save image 15975 with dist 0.0
# Save image 15985 with dist 0.0
# Save image 15995 with dist 0.0
# Save image 16005 with dist 0.0
# Save image 16014 with dist 0.0
# Save image 16024 with dist 0.0
# Save image 16034 with dist 0.0
# Save image 16043 with dist 0.0
# Save image 16053 with dist 0.0
# Save image 16062 with dist 0.0
# Save image 16071 with dist 0.0
# Save image 16080 with dist 0.0
# Save image 16089 with dist 0.0
# Save image 16098 with dist 0.0
# Save image 16107 with dist 0.0
# Save image 16117 with dist 0.0
# Save image 16127 with dist 0.0
# Save image 16136 with dist 0.0
# Save image 16145 with dist 0.0
# Save image 16155 with dist 0.0
# Save image 16163 with dist 0.0
# Save image 16172 with dist 0.0
# Save image 16181 with dist 0.0
# Save image 16190 with dist 0.0
# Save image 16198 with dist 0.0
# Save image 16208 with dist 0.0
# Save image 16217 with dist 0.0
# Save image 16225 with dist 0.0
# Save image 16233 with dist 0.0
# Save image 16241 with dist 0.0
# Save image 16249 with dist 0.0
# Save image 16257 with dist 0.0
# Save image 16265 with dist 0.0
# Save image 16273 with dist 0.0
# Save image 16282 with dist 0.0
# Save image 16290 with dist 0.0
# Save image 16298 with dist 0.0
# Save image 16307 with dist 0.0
# Save image 16315 with dist 0.0
# Save image 16323 with dist 0.0
# Save image 16331 with dist 0.0
# Save image 16339 with dist 0.0
# Save image 16348 with dist 0.0
# Save image 16356 with dist 0.0
# Save image 16364 with dist 0.0
# Save image 16372 with dist 0.0
# Save image 16381 with dist 0.0
# Save image 16389 with dist 0.0
# Save image 16397 with dist 0.0
# Save image 16405 with dist 0.0
# Save image 16412 with dist 0.0
# Save image 16421 with dist 0.0
# Save image 16429 with dist 0.0
# Save image 16437 with dist 0.0
# Save image 16446 with dist 0.0
# Save image 16454 with dist 0.0
# Save image 16462 with dist 0.0
# Save image 16470 with dist 0.0
# Save image 16479 with dist 0.0
# Save image 16488 with dist 0.0
# Save image 16497 with dist 0.0
# Save image 16507 with dist 0.0
# Save image 16515 with dist 0.0
# Save image 16524 with dist 0.0
# Save image 16533 with dist 0.0
# Save image 16542 with dist 0.0
# Save image 16551 with dist 0.0
# Save image 16559 with dist 0.0
# Save image 16568 with dist 0.0
# Save image 16577 with dist 0.0
# Save image 16586 with dist 0.0
# Save image 16594 with dist 0.0
# Save image 16603 with dist 0.0
# Save image 16610 with dist 0.0
# Save image 16618 with dist 0.0
# Save image 16627 with dist 0.0
# Save image 16636 with dist 0.0
# Save image 16644 with dist 0.0
# Save image 16653 with dist 0.0
# Save image 16661 with dist 0.0
# Save image 16669 with dist 0.0
# Save image 16677 with dist 0.0
# Save image 16687 with dist 0.0
# Save image 16695 with dist 0.0
# Save image 16703 with dist 0.0
# Save image 16711 with dist 0.0
# Save image 16718 with dist 0.0
# Save image 16726 with dist 0.0
# Save image 16733 with dist 0.0
# Save image 16740 with dist 0.0
# Save image 16747 with dist 0.0
# Save image 16754 with dist 0.0
# Save image 16762 with dist 0.0
# Save image 16769 with dist 0.0
# Save image 16776 with dist 0.0
# Save image 16784 with dist 0.0
# Save image 16790 with dist 0.0
# Save image 16797 with dist 0.0
# Save image 16804 with dist 0.0
# Save image 16810 with dist 0.0
# Save image 16817 with dist 0.0
# Save image 16824 with dist 0.0
# Save image 16831 with dist 0.0
# Save image 16837 with dist 0.0
# Save image 16844 with dist 0.0
# Save image 16851 with dist 0.0
# Save image 16857 with dist 0.0
# Save image 16864 with dist 0.0
# Save image 16871 with dist 0.0
# Save image 16877 with dist 0.0
# Save image 16884 with dist 0.0
# Save image 16891 with dist 0.0
# Save image 16897 with dist 0.0
# Save image 16904 with dist 0.0
# Save image 16911 with dist 0.0
# Save image 16918 with dist 0.0
# Save image 16925 with dist 0.0
# Save image 16931 with dist 0.0
# Save image 16938 with dist 0.0
# Save image 16945 with dist 0.0
# Save image 16952 with dist 0.0
# Save image 16959 with dist 0.0
# Save image 16964 with dist 0.0
# Save image 16971 with dist 0.0
# Save image 16978 with dist 0.0
# Save image 16985 with dist 0.0
# Save image 16992 with dist 0.0
# Save image 16999 with dist 0.0
# Save image 17007 with dist 0.0
# Save image 17014 with dist 0.0
# Save image 17023 with dist 0.0
# Save image 17030 with dist 0.0
# Save image 17038 with dist 0.0
# Save image 17045 with dist 0.0
# Save image 17052 with dist 0.0
# Save image 17058 with dist 0.0
# Save image 17066 with dist 0.0
# Save image 17073 with dist 0.0
# Save image 17080 with dist 0.0
# Save image 17088 with dist 0.0
# Save image 17095 with dist 0.0
# Save image 17103 with dist 0.0
# Save image 17110 with dist 0.0
# Save image 17118 with dist 0.0
# Save image 17126 with dist 0.0
# Save image 17133 with dist 0.0
# Save image 17141 with dist 0.0
# Save image 17148 with dist 0.0
# Save image 17156 with dist 0.0
# Save image 17160 with dist 0.0
# Save image 17167 with dist 0.0
# Save image 17176 with dist 0.0
# Save image 17185 with dist 0.0
# Save image 17194 with dist 0.0
# Save image 17203 with dist 0.0
# Save image 17212 with dist 0.0
# Save image 17222 with dist 0.0
# Save image 17231 with dist 0.0
# Save image 17241 with dist 0.0
# Save image 17251 with dist 0.0
# Save image 17260 with dist 0.0
# Save image 17270 with dist 0.0
# Save image 17280 with dist 0.0
# Save image 17292 with dist 0.0
# Save image 17303 with dist 0.0
# Save image 17312 with dist 0.569363265366084
# Save image 17319 with dist 0.37359067417394276
# Save image 17327 with dist 0.0
# Save image 17338 with dist 0.0
# Save image 17350 with dist 0.0
# Save image 17360 with dist 0.0
# Save image 17367 with dist 0.09249152976979559
# Save image 17378 with dist 0.0
# Save image 17389 with dist 0.0
# Save image 17407 with dist 0.0
# Save image 17415 with dist 0.0
# Save image 17424 with dist 0.0
# Save image 17434 with dist 0.0
# Save image 17443 with dist 0.0
# Save image 17453 with dist 0.0
# Save image 17459 with dist 0.0
# Save image 17466 with dist 0.0
# Save image 17474 with dist 0.0
# Save image 17481 with dist 0.0
# Save image 17488 with dist 0.0
# Save image 17495 with dist 0.0
# Save image 17501 with dist 0.0
# Save image 17508 with dist 0.0
# Save image 17514 with dist 0.0
# Save image 17521 with dist 0.0
# Save image 17527 with dist 0.0
# Save image 17533 with dist 0.0
# Save image 17539 with dist 0.0
# Save image 17545 with dist 0.0
# Save image 17551 with dist 0.0
# Save image 17557 with dist 0.0
# Save image 17563 with dist 0.0
# Save image 17568 with dist 0.0
# Save image 17574 with dist 0.0
# Save image 17580 with dist 0.0
# Save image 17585 with dist 0.0
# Save image 17591 with dist 0.0
# Save image 17596 with dist 0.0
# Save image 17602 with dist 0.0
# Save image 17607 with dist 0.0
# Save image 17613 with dist 0.0
# Save image 17619 with dist 0.0
# Save image 17624 with dist 0.0
# Save image 17630 with dist 0.0
# Save image 17636 with dist 0.0
# Save image 17642 with dist 0.0
# Save image 17648 with dist 0.0
# Save image 17654 with dist 0.0
# Save image 17660 with dist 0.0
# Save image 17665 with dist 0.0
# Save image 17671 with dist 0.0
# Save image 17677 with dist 0.0
# Save image 17683 with dist 0.0
# Save image 17689 with dist 0.0
# Save image 17695 with dist 0.0
# Save image 17700 with dist 0.0
# Save image 17706 with dist 0.0
# Save image 17711 with dist 0.0
# Save image 17717 with dist 0.0
# Save image 17723 with dist 0.0
# Save image 17729 with dist 0.0
# Save image 17735 with dist 0.0
# Save image 17741 with dist 0.0
# Save image 17747 with dist 0.0
# Save image 17753 with dist 0.0
# Save image 17759 with dist 0.0
# Save image 17765 with dist 0.0
# Save image 17771 with dist 0.0
# Save image 17777 with dist 0.0
# Save image 17783 with dist 0.0
# Save image 17789 with dist 0.0
# Save image 17795 with dist 0.0
# Save image 17801 with dist 0.0
# Save image 17807 with dist 0.0
# Save image 17811 with dist 0.0
# Save image 17817 with dist 0.0
# Save image 17823 with dist 0.0
# Save image 17829 with dist 0.0
# Save image 17834 with dist 0.0
# Save image 17840 with dist 0.0
# Save image 17846 with dist 0.0
# Save image 17852 with dist 0.0
# Save image 17858 with dist 0.0
# Save image 17863 with dist 0.0
# Save image 17869 with dist 0.0
# Save image 17875 with dist 0.0
# Save image 17880 with dist 0.0
# Save image 17885 with dist 0.0
# Save image 17890 with dist 0.0
# Save image 17895 with dist 0.0
# Save image 17900 with dist 0.0
# Save image 17905 with dist 0.0
# Save image 17910 with dist 0.0
# Save image 17914 with dist 0.0
# Save image 17919 with dist 0.0
# Save image 17924 with dist 0.0
# Save image 17929 with dist 0.0
# Save image 17934 with dist 0.0
# Save image 17939 with dist 0.0
# Save image 17944 with dist 0.0
# Save image 17949 with dist 0.0
# Save image 17954 with dist 0.0
# Save image 17960 with dist 0.0
# Save image 17964 with dist 0.0
# Save image 17969 with dist 0.0
# Save image 17974 with dist 0.0
# Save image 17979 with dist 0.0
# Save image 17984 with dist 0.0
# Save image 17989 with dist 0.0
# Save image 17994 with dist 0.0
# Save image 17999 with dist 0.0
# Save image 18004 with dist 0.0
# Save image 18009 with dist 0.0
# Save image 18014 with dist 0.0
# Save image 18019 with dist 0.0
# Save image 18024 with dist 0.0
# Save image 18029 with dist 0.0
# Save image 18035 with dist 0.0
# Save image 18040 with dist 0.0
# Save image 18045 with dist 0.0
# Save image 18050 with dist 0.0
# Save image 18055 with dist 0.0
# Save image 18060 with dist 0.0
# Save image 18065 with dist 0.0
# Save image 18070 with dist 0.0
# Save image 18075 with dist 0.0
# Save image 18080 with dist 0.0
# Save image 18085 with dist 0.0
# Save image 18090 with dist 0.0
# Save image 18095 with dist 0.0
# Save image 18100 with dist 0.0
# Save image 18105 with dist 0.0
# Save image 18109 with dist 0.0
# Save image 18114 with dist 0.0
# Save image 18119 with dist 0.0
# Save image 18124 with dist 0.0
# Save image 18129 with dist 0.0
# Save image 18134 with dist 0.0
# Save image 18139 with dist 0.0
# Save image 18144 with dist 0.0
# Save image 18149 with dist 0.0
# Save image 18154 with dist 0.0
# Save image 18159 with dist 0.0
# Save image 18164 with dist 0.0
# Save image 18169 with dist 0.0
# Save image 18174 with dist 0.0
# Save image 18179 with dist 0.0
# Save image 18184 with dist 0.0
# Save image 18189 with dist 0.0
# Save image 18194 with dist 0.0
# Save image 18199 with dist 0.0
# Save image 18204 with dist 0.0
# Save image 18210 with dist 0.0
# Save image 18215 with dist 0.0
# Save image 18220 with dist 0.0
# Save image 18225 with dist 0.0
# Save image 18230 with dist 0.0
# Save image 18235 with dist 0.0
# Save image 18240 with dist 0.0
# Save image 18245 with dist 0.0
# Save image 18250 with dist 0.0
# Save image 18255 with dist 0.0
# Save image 18260 with dist 0.0
# Save image 18265 with dist 0.0
# Save image 18270 with dist 0.0
# Save image 18275 with dist 0.0
# Save image 18280 with dist 0.0
# Save image 18285 with dist 0.0
# Save image 18290 with dist 0.0
# Save image 18296 with dist 0.0
# Save image 18301 with dist 0.0
# Save image 18306 with dist 0.0
# Save image 18311 with dist 0.0
# Save image 18316 with dist 0.0
# Save image 18322 with dist 0.0
# Save image 18328 with dist 0.0
# Save image 18335 with dist 0.0
# Save image 18341 with dist 0.0
# Save image 18347 with dist 0.0
# Save image 18353 with dist 0.0
# Save image 18359 with dist 0.0
# Save image 18365 with dist 0.0
# Save image 18371 with dist 0.0
# Save image 18377 with dist 0.0
# Save image 18383 with dist 0.0
# Save image 18390 with dist 0.0
# Save image 18396 with dist 0.0
# Save image 18402 with dist 0.0
# Save image 18409 with dist 0.0
# Save image 18415 with dist 0.0
# Save image 18422 with dist 0.0
# Save image 18429 with dist 0.0
# Save image 18435 with dist 0.0
# Save image 18442 with dist 0.0
# Save image 18449 with dist 0.0
# Save image 18456 with dist 0.0
# Save image 18462 with dist 0.0
# Save image 18469 with dist 0.0
# Save image 18476 with dist 0.0
# Save image 18483 with dist 0.0
# Save image 18490 with dist 0.0
# Save image 18497 with dist 0.0
# Save image 18506 with dist 0.0
# Save image 18514 with dist 0.0
# Save image 18523 with dist 0.0
# Save image 18531 with dist 0.0
# Save image 18540 with dist 0.0
# Save image 18549 with dist 0.0
# Save image 18558 with dist 0.0
# Save image 18567 with dist 0.0
# Save image 18576 with dist 0.0
# Save image 18586 with dist 0.0
# Save image 18596 with dist 0.0
# Save image 18605 with dist 0.0
# Save image 18615 with dist 0.0
# Save image 18624 with dist 0.0
# Save image 18634 with dist 0.0
# Save image 18645 with dist 0.0
# Save image 18654 with dist 0.0
# Save image 18664 with dist 0.0
# Save image 18673 with dist 0.0
# Save image 18684 with dist 0.0
# Save image 18695 with dist 0.0
# Save image 18705 with dist 0.0
# Save image 18716 with dist 0.0
# Save image 18726 with dist 0.0
# Save image 18737 with dist 0.0
# Save image 18747 with dist 0.0
# Save image 18758 with dist 0.0
# Save image 18767 with dist 0.0
# Save image 18777 with dist 0.0
# Save image 18788 with dist 0.0
# Save image 18798 with dist 0.0
